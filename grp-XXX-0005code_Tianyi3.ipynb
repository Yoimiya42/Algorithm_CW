# %% [markdown]
# # COMP0005 - GROUP COURSEWORK
# # Experimental Evaluation of Search Data Structures and Algorithms

# %% [markdown]
# The cell below defines **AbstractSearchInterface**, an interface to support basic insert/search operations; you will need to implement this three times, to realise your three search data structures of choice among: (1) *2-3 Tree*, (2) *AVL Tree*, (3) *LLRB BST*; (4) *B-Tree*; and (5) *Scapegoat Tree*. <br><br>**Do NOT modify the next cell** - use the dedicated cells further below for your implementation instead. <br>

# %%
# DO NOT MODIFY THIS CELL

from abc import ABC, abstractmethod  

class AbstractSearchInterface(ABC):
    '''
    Abstract class to support search/insert operations (plus underlying data structure)
    
    '''
        
    @abstractmethod
    def insertElement(self, element):     
        '''
        Insert an element in a search tree
            Parameters:
                    element: string to be inserted in the search tree (string)

            Returns:
                    "True" after successful insertion, "False" if element is already present (bool)
        '''
        
        pass 
    

    @abstractmethod
    def searchElement(self, element):
        '''
        Search for an element in a search tree
            Parameters:
                    element: string to be searched in the search tree (string)

            Returns:
                    "True" if element is found, "False" otherwise (bool)
        '''

        pass

# %% [markdown]
# Use the cell below to define any auxiliary data structure and python function you may need. Leave the implementation of the main API to the next code cells instead.

# %%
# ADD AUXILIARY DATA STRUCTURE DEFINITIONS AND HELPER CODE HERE
class Node: 
    def __init__(self, element): 
        self.left = None
        self.right = None
        self.parent = None
        self.element = element
        
class Node1:
    def __init__(self):
        self.keys = []
        self.children = []

    def is_leaf(self):
        return len(self.children) == 0

    def insert_key(self, key):
        # Insert key into the keys list in sorted order
        index = 0
        while index < len(self.keys) and key > self.keys[index]:
            index += 1
        self.keys.insert(index, key)

    def split(self):
        # Split the node into two nodes and return the middle key
        mid_index = len(self.keys) // 2
        mid_key = self.keys[mid_index]

        left = Node1()
        left.keys = self.keys[:mid_index]

        right = Node1()
        right.keys = self.keys[mid_index + 1:]

        if not self.is_leaf():
            # Split the children accordingly
            left.children = self.children[:mid_index + 1]
            right.children = self.children[mid_index + 1:]

        return mid_key, left, right
        
class LLRBNode:
    def __init__(self, key, color, left=None, right=None):
        self.key = key
        self.color = color  # True indicates red, False indicates black
        self.left = left
        self.right = right

# %% [markdown]
# Use the cell below to implement the requested API by means of **2-3 Tree** (if among your chosen data structure).

# %%
class TwoThreeTree:
    def __init__(self):
        self.root = Node1()

    def searchElement(self, key):
        node = self.root
        while node:
            found = False
            for i in range(len(node.keys)):
                if key == node.keys[i]:
                    return True
                elif key < node.keys[i]:
                    if node.is_leaf():
                        return False
                    node = node.children[i]
                    found = True
                    break
            if not found:
                if node.is_leaf():
                    return False
                node = node.children[-1]
        return False

    def insertElement(self, key):
        split_result = self._insert(self.root, key)
        if split_result:
            # Root needs to split
            mid_key, left, right = split_result
            new_root = Node1()
            new_root.keys.append(mid_key)
            new_root.children.append(left)
            new_root.children.append(right)
            self.root = new_root

    def _insert(self, node, key):
        if node.is_leaf():
            node.insert_key(key)
            if len(node.keys) > 2:
                return node.split()
            return None
        else:
            # Find the appropriate child to insert
            child_index = 0
            while child_index < len(node.keys) and key >= node.keys[child_index]:
                child_index += 1

            split_result = self._insert(node.children[child_index], key)
            if split_result:
                mid_key, left, right = split_result

                # Insert the mid_key into current node
                insert_index = 0
                while insert_index < len(node.keys) and mid_key > node.keys[insert_index]:
                    insert_index += 1
                node.keys.insert(insert_index, mid_key)

                # Replace the child with left and right
                node.children.pop(child_index)
                node.children.insert(child_index, right)
                node.children.insert(child_index, left)

                if len(node.keys) > 2:
                    return node.split()
            return None
        
    def height(self):
        """Calculate the height of the 2-3 tree."""
        if not self.root.keys:  # if root null, height is 0
            return 0
        return self._height(self.root)

    def _height(self, node):
        """Helper method to recursively calculate height."""
        if node.is_leaf():
            return 1  
       
        return 1 + max(self._height(child) for child in node.children)

# %%
class AVLTree(AbstractSearchInterface):
        
    def insertElement(self, element):
        inserted = False
        # ADD YOUR CODE HERE
      
        
        return inserted
    
    

    def searchElement(self, element):     
        found = False
        # ADD YOUR CODE HERE

        
        return found

# %% [markdown]
# Use the cell below to implement the requested API by means of **LLRB BST** (if among your chosen data structure).

# %%
class LLRBTree:
    def __init__(self):
        self.root = None

    def is_red(self, node):
        return node is not None and node.color
    
    def _rotate_left(self, h:LLRBNode):
        x = h.right
        h.right = x.left
        x.left = h
        x.color = h.color
        h.color = True
        return x

    def _rotate_right(self, h):
        x = h.left
        h.left = x.right
        x.right = h
        x.color = h.color
        h.color = True
        return x

    def _flip_colors(self, h):
        h.color = not h.color
        if h.left:
            h.left.color = not h.left.color
        if h.right:
            h.right.color = not h.right.color

    def _insert(self, h, key):
        if h is None:
            return LLRBNode(key, True)
        if key == h.key:
            return h  # Ignore duplicates
        if key < h.key:
            h.left = self._insert(h.left, key)
        elif key > h.key:
            h.right = self._insert(h.right, key)
        if self.is_red(h.right) and not self.is_red(h.left):
            h = self._rotate_left(h)
        if self.is_red(h.left) and self.is_red(h.left.left):
            h = self._rotate_right(h)
        if self.is_red(h.left) and self.is_red(h.right):
            self._flip_colors(h)
        return h

    def insertElement(self, key):
        self.root = self._insert(self.root, key)
        self.root.color = False

    def searchElement(self, key):
        return self._search(self.root, key)

    def _search(self, node, key):
        if node is None:
            return False
        if key < node.key:
            return self._search(node.left, key)
        elif key > node.key:
            return self._search(node.right, key)
        else:
            return True
    
    def height(self):
        return self._height(self.root)

    def _height(self, node):
        if node is None:
            return 0
        return 1 + max(self._height(node.left), self._height(node.right))

# %% [markdown]
# Use the cell below to implement the requested API by means of **B-Tree** (if among your chosen data structure).

# %%
class BTree(AbstractSearchInterface):
        
    def insertElement(self, element):
        inserted = False
        # ADD YOUR CODE HERE
      
        
        return inserted
    
    

    def searchElement(self, element):     
        found = False
        # ADD YOUR CODE HERE

        
        return found

# %% [markdown]
# Use the cell below to implement the requested API by means of **Scapegoat Tree** (if among your chosen data structure).

# %%
# DO NOT MODIFY THIS CELL

import math
from collections import deque





# < works on strings

class ScapegoatTree(AbstractSearchInterface):
    
    def __init__(self):
        self.totalSize = 0
        self.root = None
    
    # Level-order traversal
    def displayLevelOrder(self):
        if self.root is None:
            print("Tree is empty")
            return
        
        queue = deque([self.root])
        
        while queue:
            node = queue.popleft()
            print(node.element, end=" ")
            
            if node.left:
                queue.append(node.left)
            if node.right:
                queue.append(node.right)
        print()

    def displayTree(self, node, level=0):
        if node is not None:
            self.displayTree(node.right, level + 1)
            print("   " * level + f"({node.element})")
            self.displayTree(node.left, level + 1)

    def preorderTraverse(self, node): 
        if node: 
            self.preorderTraverse(node.left) 
            self.preorderTraverse(node.right) 
        
    def getSize(self, node):
        if node == None:
            return 0
        return 1 + self.getSize(node.left) + self.getSize(node.right)
        
    def insertElement(self, element):
        inserted = False
        # ADD YOUR CODE HERE

        newNode = Node(element)

        if self.root == None:
            self.root = newNode
            self.totalSize += 1
            return True
    
        currNode = self.root
        treeDepth = 0

        while currNode:
            parentNode = currNode
            treeDepth += 1
            if newNode.element < currNode.element:
                currNode = currNode.left
            elif newNode.element > currNode.element:
                currNode = currNode.right
            else:
                print("Element already in tree")
                return False
        
        newNode.parent = parentNode
        if newNode.element < parentNode.element:
            parentNode.left = newNode
        else:
            parentNode.right = newNode
        
        self.totalSize +=1


        if treeDepth > (2.4663034623764317 * math.log(self.totalSize, 3)): # scapegoat tree balancing condition

            #find scapegoat
            while (3*self.getSize(parentNode) <= 2* self.getSize(parentNode.parent)):
                parentNode = parentNode.parent # moves up the tree
            self.rebuild(parentNode.parent) 


        return True
    
    def rebuild(self, scapegoat):
        subtreeSize = self.getSize(scapegoat)
        parentNode = scapegoat.parent
        array = [None]*subtreeSize

        self.flattenSubtree(scapegoat,array, 0)
        for node in array:
            print(node.element)

        #attaching rebuilt subtree
        if parentNode is None:
            self.root = self.buildNewSubtree(array, 0, subtreeSize)
            self.root.parent = None
        elif parentNode.right == scapegoat:
            parentNode.right = self.buildNewSubtree(array, 0, subtreeSize)
            parentNode.right.parent = parentNode
        else:
            parentNode.left = self.buildNewSubtree(array, 0, subtreeSize)
            parentNode.left.parent = parentNode

    def buildNewSubtree(self, array, index, size):
        if size == 0:
            return None

        centre = size // 2

        node = array[index + centre]
        
        node.left = self.buildNewSubtree(array, index, centre)
        if node.left:
            node.left.parent = node
        
        node.right = self.buildNewSubtree(array, index + centre + 1, size - centre - 1)
        if node.right:
            node.right.parent = node
        
        return node

    
    def flattenSubtree(self, node, array, index):
        if node is None:
            return index
        index = self.flattenSubtree(node.left, array, index)

        array[index] = node
        index +=1

        index = self.flattenSubtree(node.right, array, index)
        return index

    def searchElement(self, element):     
        found = False
        # ADD YOUR CODE HERE

        currNode = self.root

        while currNode:
            if element < currNode.element:
                currNode = currNode.left
            elif element > currNode.element:
                currNode = currNode.right
            else:
                found = True
                break

        return found 

    def height(self):
        return self._height(self.root)

    def _height(self, node):
        if node is None:
            return 0
        return 1 + max(self._height(node.left), self._height(node.right))

# %% [markdown]
# Use the cell below to implement the **synthetic data generator** needed by your experimental framework (be mindful of code readability and reusability).

# %%
import random
import string

class TestDataGenerator:
    def __init__(self, data_size=4000, string_length=8, distribution="random"):
        """
        Parameters
        ----------
        data_size : int
            Number of strings to generate (default 2000).
        string_length : int
            Length of each string (default 8).
        distribution : str
            'random', 'sorted', 'almost_sorted', or 'repetitive'.
        """
        self.data_size = data_size
        self.string_length = string_length
        self.distribution = distribution
        self.alphabet = string.ascii_lowercase

    def generate_data(self):
        """Generate and return a list of strings based on the distribution."""
        if self.distribution == "random":
            return self._generate_random_strings()
        elif self.distribution == "sorted":
            return sorted(self._generate_random_strings())
        elif self.distribution == "almost_sorted":
            return self._generate_almost_sorted_strings()
        elif self.distribution == "repetitive":
            return self._generate_repetitive_strings()
        # edge case: same  string
        elif self.distribution == "all_same":
            return self._generate_all_same_strings()
        # edge case: reverse order
        elif self.distribution == "reverse_sorted":
            return sorted(self._generate_random_strings(), reverse=True)
        else:
            return self._generate_random_strings()

    def _generate_random_strings(self):
        """Generate random strings with minimal collision checks."""
        data = []
        seen = set()
        for _ in range(self.data_size):
            while True:
                s = ''.join(random.choices(self.alphabet, k=self.string_length))
                if s not in seen:
                    seen.add(s)
                    data.append(s)
                    break
        return data

    '''def _generate_almost_sorted_strings(self):
        """Generate almost sorted strings by perturbing sorted random strings."""
        data = sorted(self._generate_random_strings())
        for _ in range(3):  
            i, j = random.sample(range(self.data_size), 2)
            data[i], data[j] = data[j], data[i]
        return data'''
    def _generate_almost_sorted_strings(self):
        """Generate almost sorted strings by perturbing sorted random strings."""
        data = sorted(self._generate_random_strings())
        for _ in range(min(3, self.data_size // 2)):  # dynamically adjust swap times
            i, j = random.sample(range(self.data_size), 2)
            data[i], data[j] = data[j], data[i]
        return data

    '''def _generate_repetitive_strings(self):
        # ensure uniqueness
        unique_count = self.data_size
        unique_strings = self._generate_random_strings()[:unique_count]
        return unique_strings'''
    def _generate_repetitive_strings(self):
        """生成具有一定重复性的唯一字符串，但限制重复度以保持测试意义"""
        unique_count = max(1, self.data_size // 10)  # 10% unique string
        unique_strings = self._generate_random_strings()[:unique_count]
        return [unique_strings[i % unique_count] for i in range(self.data_size)]
    # edfe case: all same input string
    def _generate_all_same_strings(self):
        """Generate a list where all strings are identical."""
        s = ''.join(random.choices(self.alphabet, k=self.string_length))
        return [s] * self.data_size

# Test
if __name__ == "__main__":
    gen = TestDataGenerator(data_size=4000, string_length=8, distribution="random")
    test = gen.generate_data()
    print(f"Generated {len(test)} strings, first 5: {test[:5]}")
# Out:
# Generated 4000 strings, first 5: ['xuidewka', 'irudcotq', 'nnxijctx', 'ifhtlmdp', 'pnbzyuqt']

# %% [markdown]
# Use the cell below to implement the requested **experimental framework** (be mindful of code readability and reusability).

# %%
import timeit

class ExperimentalFramework:
    def __init__(self, data_structures, data_generator, repeat=5):
        self.data_structures = data_structures
        self.data_generator = data_generator
        self.repeat = repeat
        self.results = {
            "total_insertion_time": {},
            "total_search_time": {},
            "avg_insertion_per_op": {},
            "avg_search_per_op": {},
           
        }

    def run_experiment(self, search_sample_size=None):
        data = self.data_generator.generate_data()
        total_strings = len(data)
        print(f"Generated {total_strings} strings ('{self.data_generator.distribution}')")

        # increase sample size
        search_sample_size = min(int(total_strings * 0.5), total_strings) if search_sample_size is None else search_sample_size
        search_data = random.sample(data, search_sample_size)

        for ds_name, ds_class in self.data_structures.items():
            print(f"Testing {ds_name}")

            # dummy tree for height check
            ds_instance = ds_class()
            for s in data:
                ds_instance.insertElement(s)
            print(f"{ds_name} - Tree height after insertion: {ds_instance.height()}")

            
            def test_insertion(ds, data):
                for s in data:
                    ds.insertElement(s)

            ds_for_ins = ds_class()
            ins_globals = {"test_insertion": test_insertion, "ds": ds_for_ins, "data": data}
            total_ins_time = timeit.timeit("test_insertion(ds, data)", globals=ins_globals, number=self.repeat)
            
            
            avg_ins_time = total_ins_time / (self.repeat * total_strings) if total_strings > 0 else 0

            # add side-effect
            def test_search(ds, search_data):
                count = 0
                for s in search_data:
                    if ds.searchElement(s):
                        count += 1
                return count

            ds_for_search = ds_class()
            for s in data:
                ds_for_search.insertElement(s)
            search_globals = {"test_search": test_search, "ds": ds_for_search, "search_data": search_data}
            total_search_time = timeit.timeit("test_search(ds, search_data)", globals=search_globals, number=self.repeat)
            
            avg_search_time = total_search_time / (self.repeat * search_sample_size) if search_sample_size > 0 else 0

            self.results["total_insertion_time"][ds_name] = total_ins_time
            self.results["total_search_time"][ds_name] = total_search_time
            self.results["avg_insertion_per_op"][ds_name] = avg_ins_time
            self.results["avg_search_per_op"][ds_name] = avg_search_time

            print(f"{ds_name} - Insert: {total_ins_time:.6f}s, Avg: {avg_ins_time:.9f}s/op")
            print(f"{ds_name} - Search: {total_search_time:.6f}s, Avg: {avg_search_time:.9f}s/op")

    def get_results(self):
        return self.results

# %% [markdown]
# Use the cell below to illustrate the python code you used to **fully evaluate** your three chosen search data structures and algortihms. The code below should illustrate, for example, how you made used of the **TestDataGenerator** class to generate test data of various size and properties; how you instatiated the **ExperimentalFramework** class to  evaluate each data structure using such data, collect information about their execution time, plot results, etc. Any results you illustrate in the companion PDF report should have been generated using the code below.

# %%
import matplotlib.pyplot as plt

# Test conditions
distributions = ["random", "sorted", "almost_sorted", "repetitive", "all_same", "reverse_sorted"]
string_length = 8
data_structures = {"2-3": TwoThreeTree, "LLRB": LLRBTree}

# Generate data_sizes with larger step
#data_sizes = list(range(50, 4001, 100))  
data_sizes = [0, 1, 10, 50] + list(range(100, 5001, 200)) + [10000]  # edge case: 0, 1, 10  stress test: 10000

# Store results
all_results = {}

num_trials = 3  
for dist in distributions:
    for size in data_sizes:
        print(f"\n=== {dist}, size={size} ===")
        avg_results = {ds_name: {"ins": [], "search": []} for ds_name in data_structures}
        
        for trial in range(num_trials):
            gen = TestDataGenerator(data_size=size, string_length=string_length, distribution=dist)
            framework = ExperimentalFramework(data_structures, gen, repeat=5)
            framework.run_experiment()  # search_sample_size dunamically adjust
            for ds_name, results in [(n, framework.get_results()) for n in data_structures]:
                avg_results[ds_name]["ins"].append(results["avg_insertion_per_op"][ds_name])
                avg_results[ds_name]["search"].append(results["avg_search_per_op"][ds_name])
                
        all_results[(dist, size)] = {
            ds_name: (sum(avg_results[ds_name]["ins"]) / num_trials,
                      sum(avg_results[ds_name]["search"]) / num_trials)
            for ds_name in data_structures
        }

# Plotting
def plot_results(all_results, data_sizes, distributions, ds_names):
    for dist in distributions:
        # plot insertion
        plt.figure(figsize=(12, 6))
        for ds in ds_names:
            ins_times = [all_results.get((dist, size), {}).get(ds, (0, 0))[0] * 1e5
                         for size in data_sizes]
            plt.plot(data_sizes, ins_times, marker='o', label=f"{ds} Insert", linewidth=1, markersize=4)
        plt.xticks(data_sizes[::2], rotation=45)
        plt.xlabel("Data Size")
        plt.ylabel("Avg Time per Insertion (10⁻⁵ s)")
        plt.title(f"Insertion Time - {dist}")
        plt.legend()
        plt.grid(True, which="both", ls="--")
        plt.tight_layout()
        plt.show()

        # plot search
        plt.figure(figsize=(12, 6))
        for ds in ds_names:
            search_times = [all_results.get((dist, size), {}).get(ds, (0, 0))[1] * 1e5
                            for size in data_sizes]
            plt.plot(data_sizes, search_times, marker='o', label=f"{ds} Search", linewidth=1, markersize=4)
        plt.xticks(data_sizes[::2], rotation=45)
        plt.xlabel("Data Size")
        plt.ylabel("Avg Time per Search (10⁻⁵ s)")
        plt.title(f"Search Time - {dist}")
        plt.legend()
        plt.grid(True, which="both", ls="--")
        plt.tight_layout()
        plt.show()



# Plot
ds_names = list(data_structures.keys())
plot_results(all_results, data_sizes, distributions, ds_names)
# Out:
# === random, size=0 ===
# Generated 0 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 0 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 0 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
#
# === random, size=1 ===
# Generated 1 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 1
# 2-3 - Insert: 0.000012s, Avg: 0.000002320s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000003s, Avg: 0.000000520s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 1 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 1
# 2-3 - Insert: 0.000007s, Avg: 0.000001400s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000002s, Avg: 0.000000360s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 1 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 1
# 2-3 - Insert: 0.000005s, Avg: 0.000000920s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000002s, Avg: 0.000000340s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
#
# === random, size=10 ===
# Generated 10 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000061s, Avg: 0.000001210s/op
# 2-3 - Search: 0.000015s, Avg: 0.000000588s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000022s, Avg: 0.000000440s/op
# LLRB - Search: 0.000012s, Avg: 0.000000460s/op
# Generated 10 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000050s, Avg: 0.000001004s/op
# 2-3 - Search: 0.000012s, Avg: 0.000000484s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000027s, Avg: 0.000000534s/op
# LLRB - Search: 0.000005s, Avg: 0.000000212s/op
# Generated 10 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000047s, Avg: 0.000000936s/op
# 2-3 - Search: 0.000010s, Avg: 0.000000408s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000023s, Avg: 0.000000468s/op
# LLRB - Search: 0.000004s, Avg: 0.000000176s/op
#
# === random, size=50 ===
# Generated 50 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000305s, Avg: 0.000001220s/op
# 2-3 - Search: 0.000086s, Avg: 0.000000687s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.000232s, Avg: 0.000000926s/op
# LLRB - Search: 0.000040s, Avg: 0.000000319s/op
# Generated 50 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000367s, Avg: 0.000001469s/op
# 2-3 - Search: 0.000072s, Avg: 0.000000577s/op
# Testing LLRB
# LLRB - Tree height after insertion: 8
# LLRB - Insert: 0.000202s, Avg: 0.000000808s/op
# LLRB - Search: 0.000038s, Avg: 0.000000301s/op
# Generated 50 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000281s, Avg: 0.000001123s/op
# 2-3 - Search: 0.000071s, Avg: 0.000000567s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.000182s, Avg: 0.000000726s/op
# LLRB - Search: 0.000031s, Avg: 0.000000251s/op
#
# === random, size=100 ===
# Generated 100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000595s, Avg: 0.000001189s/op
# 2-3 - Search: 0.000152s, Avg: 0.000000609s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.000538s, Avg: 0.000001075s/op
# LLRB - Search: 0.000082s, Avg: 0.000000329s/op
# Generated 100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000606s, Avg: 0.000001211s/op
# 2-3 - Search: 0.000157s, Avg: 0.000000629s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.000516s, Avg: 0.000001033s/op
# LLRB - Search: 0.000079s, Avg: 0.000000316s/op
# Generated 100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.001010s, Avg: 0.000002020s/op
# 2-3 - Search: 0.000206s, Avg: 0.000000823s/op
# Testing LLRB
# LLRB - Tree height after insertion: 9
# LLRB - Insert: 0.000493s, Avg: 0.000000987s/op
# LLRB - Search: 0.000083s, Avg: 0.000000334s/op
#
# === random, size=300 ===
# Generated 300 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 7
# 2-3 - Insert: 0.002320s, Avg: 0.000001547s/op
# 2-3 - Search: 0.000653s, Avg: 0.000000871s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.002007s, Avg: 0.000001338s/op
# LLRB - Search: 0.000287s, Avg: 0.000000383s/op
# Generated 300 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 7
# 2-3 - Insert: 0.002446s, Avg: 0.000001631s/op
# 2-3 - Search: 0.000946s, Avg: 0.000001262s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.002102s, Avg: 0.000001402s/op
# LLRB - Search: 0.000324s, Avg: 0.000000433s/op
# Generated 300 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 7
# 2-3 - Insert: 0.003296s, Avg: 0.000002197s/op
# 2-3 - Search: 0.000943s, Avg: 0.000001257s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.002933s, Avg: 0.000001955s/op
# LLRB - Search: 0.000506s, Avg: 0.000000674s/op
#
# === random, size=500 ===
# Generated 500 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.005981s, Avg: 0.000002393s/op
# 2-3 - Search: 0.001968s, Avg: 0.000001574s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.003644s, Avg: 0.000001457s/op
# LLRB - Search: 0.000491s, Avg: 0.000000392s/op
# Generated 500 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 7
# 2-3 - Insert: 0.003993s, Avg: 0.000001597s/op
# 2-3 - Search: 0.001015s, Avg: 0.000000812s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.006588s, Avg: 0.000002635s/op
# LLRB - Search: 0.000810s, Avg: 0.000000648s/op
# Generated 500 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 7
# 2-3 - Insert: 0.006130s, Avg: 0.000002452s/op
# 2-3 - Search: 0.001882s, Avg: 0.000001506s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.006883s, Avg: 0.000002753s/op
# LLRB - Search: 0.000807s, Avg: 0.000000646s/op
#
# === random, size=700 ===
# Generated 700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.009230s, Avg: 0.000002637s/op
# 2-3 - Search: 0.002998s, Avg: 0.000001713s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.008532s, Avg: 0.000002438s/op
# LLRB - Search: 0.001186s, Avg: 0.000000678s/op
# Generated 700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.009229s, Avg: 0.000002637s/op
# 2-3 - Search: 0.002757s, Avg: 0.000001575s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.005536s, Avg: 0.000001582s/op
# LLRB - Search: 0.000718s, Avg: 0.000000410s/op
# Generated 700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.006773s, Avg: 0.000001935s/op
# 2-3 - Search: 0.001580s, Avg: 0.000000903s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.004671s, Avg: 0.000001334s/op
# LLRB - Search: 0.000700s, Avg: 0.000000400s/op
#
# === random, size=900 ===
# Generated 900 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.007484s, Avg: 0.000001663s/op
# 2-3 - Search: 0.002517s, Avg: 0.000001119s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.007976s, Avg: 0.000001773s/op
# LLRB - Search: 0.000953s, Avg: 0.000000424s/op
# Generated 900 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.007582s, Avg: 0.000001685s/op
# 2-3 - Search: 0.002232s, Avg: 0.000000992s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.007885s, Avg: 0.000001752s/op
# LLRB - Search: 0.001058s, Avg: 0.000000470s/op
# Generated 900 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.008064s, Avg: 0.000001792s/op
# 2-3 - Search: 0.002855s, Avg: 0.000001269s/op
# Testing LLRB
# LLRB - Tree height after insertion: 14
# LLRB - Insert: 0.008645s, Avg: 0.000001921s/op
# LLRB - Search: 0.001918s, Avg: 0.000000852s/op
#
# === random, size=1100 ===
# Generated 1100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.016071s, Avg: 0.000002922s/op
# 2-3 - Search: 0.004928s, Avg: 0.000001792s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.015212s, Avg: 0.000002766s/op
# LLRB - Search: 0.001217s, Avg: 0.000000443s/op
# Generated 1100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.010478s, Avg: 0.000001905s/op
# 2-3 - Search: 0.002937s, Avg: 0.000001068s/op
# Testing LLRB
# LLRB - Tree height after insertion: 14
# LLRB - Insert: 0.013286s, Avg: 0.000002416s/op
# LLRB - Search: 0.001217s, Avg: 0.000000443s/op
# Generated 1100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.013926s, Avg: 0.000002532s/op
# 2-3 - Search: 0.003032s, Avg: 0.000001103s/op
# Testing LLRB
# LLRB - Tree height after insertion: 14
# LLRB - Insert: 0.009338s, Avg: 0.000001698s/op
# LLRB - Search: 0.001574s, Avg: 0.000000573s/op
#
# === random, size=1300 ===
# Generated 1300 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.015037s, Avg: 0.000002313s/op
# 2-3 - Search: 0.004488s, Avg: 0.000001381s/op
# Testing LLRB
# LLRB - Tree height after insertion: 14
# LLRB - Insert: 0.010629s, Avg: 0.000001635s/op
# LLRB - Search: 0.001434s, Avg: 0.000000441s/op
# Generated 1300 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.011931s, Avg: 0.000001836s/op
# 2-3 - Search: 0.004098s, Avg: 0.000001261s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.010347s, Avg: 0.000001592s/op
# LLRB - Search: 0.001540s, Avg: 0.000000474s/op
# Generated 1300 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.011541s, Avg: 0.000001775s/op
# 2-3 - Search: 0.004259s, Avg: 0.000001310s/op
# Testing LLRB
# LLRB - Tree height after insertion: 14
# LLRB - Insert: 0.009957s, Avg: 0.000001532s/op
# LLRB - Search: 0.001451s, Avg: 0.000000447s/op
#
# === random, size=1500 ===
# Generated 1500 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.016411s, Avg: 0.000002188s/op
# 2-3 - Search: 0.003938s, Avg: 0.000001050s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.013244s, Avg: 0.000001766s/op
# LLRB - Search: 0.001660s, Avg: 0.000000443s/op
# Generated 1500 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.012873s, Avg: 0.000001716s/op
# 2-3 - Search: 0.003935s, Avg: 0.000001049s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.013191s, Avg: 0.000001759s/op
# LLRB - Search: 0.001974s, Avg: 0.000000526s/op
# Generated 1500 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.015727s, Avg: 0.000002097s/op
# 2-3 - Search: 0.007173s, Avg: 0.000001913s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.015128s, Avg: 0.000002017s/op
# LLRB - Search: 0.002185s, Avg: 0.000000583s/op
#
# === random, size=1700 ===
# Generated 1700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.016343s, Avg: 0.000001923s/op
# 2-3 - Search: 0.007314s, Avg: 0.000001721s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.013308s, Avg: 0.000001566s/op
# LLRB - Search: 0.002179s, Avg: 0.000000513s/op
# Generated 1700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.017524s, Avg: 0.000002062s/op
# 2-3 - Search: 0.005332s, Avg: 0.000001255s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.016384s, Avg: 0.000001928s/op
# LLRB - Search: 0.002811s, Avg: 0.000000661s/op
# Generated 1700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.017848s, Avg: 0.000002100s/op
# 2-3 - Search: 0.006674s, Avg: 0.000001570s/op
# Testing LLRB
# LLRB - Tree height after insertion: 14
# LLRB - Insert: 0.013964s, Avg: 0.000001643s/op
# LLRB - Search: 0.004435s, Avg: 0.000001043s/op
#
# === random, size=1900 ===
# Generated 1900 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.016924s, Avg: 0.000001781s/op
# 2-3 - Search: 0.008280s, Avg: 0.000001743s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.019814s, Avg: 0.000002086s/op
# LLRB - Search: 0.002565s, Avg: 0.000000540s/op
# Generated 1900 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.018373s, Avg: 0.000001934s/op
# 2-3 - Search: 0.005525s, Avg: 0.000001163s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.015279s, Avg: 0.000001608s/op
# LLRB - Search: 0.002423s, Avg: 0.000000510s/op
# Generated 1900 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.016526s, Avg: 0.000001740s/op
# 2-3 - Search: 0.006525s, Avg: 0.000001374s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.015822s, Avg: 0.000001665s/op
# LLRB - Search: 0.002539s, Avg: 0.000000535s/op
#
# === random, size=2100 ===
# Generated 2100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.018511s, Avg: 0.000001763s/op
# 2-3 - Search: 0.006495s, Avg: 0.000001237s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.018600s, Avg: 0.000001771s/op
# LLRB - Search: 0.003004s, Avg: 0.000000572s/op
# Generated 2100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.018787s, Avg: 0.000001789s/op
# 2-3 - Search: 0.007090s, Avg: 0.000001350s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.019760s, Avg: 0.000001882s/op
# LLRB - Search: 0.002686s, Avg: 0.000000512s/op
# Generated 2100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.019023s, Avg: 0.000001812s/op
# 2-3 - Search: 0.007285s, Avg: 0.000001388s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.018788s, Avg: 0.000001789s/op
# LLRB - Search: 0.002391s, Avg: 0.000000455s/op
#
# === random, size=2300 ===
# Generated 2300 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.019363s, Avg: 0.000001684s/op
# 2-3 - Search: 0.008370s, Avg: 0.000001456s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.020594s, Avg: 0.000001791s/op
# LLRB - Search: 0.002720s, Avg: 0.000000473s/op
# Generated 2300 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.022155s, Avg: 0.000001926s/op
# 2-3 - Search: 0.007542s, Avg: 0.000001312s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.020124s, Avg: 0.000001750s/op
# LLRB - Search: 0.003230s, Avg: 0.000000562s/op
# Generated 2300 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.023083s, Avg: 0.000002007s/op
# 2-3 - Search: 0.007276s, Avg: 0.000001265s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.024110s, Avg: 0.000002096s/op
# LLRB - Search: 0.002964s, Avg: 0.000000515s/op
#
# === random, size=2500 ===
# Generated 2500 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.025726s, Avg: 0.000002058s/op
# 2-3 - Search: 0.009099s, Avg: 0.000001456s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.026624s, Avg: 0.000002130s/op
# LLRB - Search: 0.005357s, Avg: 0.000000857s/op
# Generated 2500 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.021075s, Avg: 0.000001686s/op
# 2-3 - Search: 0.008039s, Avg: 0.000001286s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.022030s, Avg: 0.000001762s/op
# LLRB - Search: 0.003112s, Avg: 0.000000498s/op
# Generated 2500 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.024396s, Avg: 0.000001952s/op
# 2-3 - Search: 0.007029s, Avg: 0.000001125s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.027128s, Avg: 0.000002170s/op
# LLRB - Search: 0.002944s, Avg: 0.000000471s/op
#
# === random, size=2700 ===
# Generated 2700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.027269s, Avg: 0.000002020s/op
# 2-3 - Search: 0.008569s, Avg: 0.000001270s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.025161s, Avg: 0.000001864s/op
# LLRB - Search: 0.003463s, Avg: 0.000000513s/op
# Generated 2700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.026250s, Avg: 0.000001944s/op
# 2-3 - Search: 0.008447s, Avg: 0.000001251s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.030398s, Avg: 0.000002252s/op
# LLRB - Search: 0.003716s, Avg: 0.000000551s/op
# Generated 2700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.026503s, Avg: 0.000001963s/op
# 2-3 - Search: 0.010013s, Avg: 0.000001483s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.025735s, Avg: 0.000001906s/op
# LLRB - Search: 0.003665s, Avg: 0.000000543s/op
#
# === random, size=2900 ===
# Generated 2900 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.028081s, Avg: 0.000001937s/op
# 2-3 - Search: 0.014169s, Avg: 0.000001954s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.032981s, Avg: 0.000002275s/op
# LLRB - Search: 0.003383s, Avg: 0.000000467s/op
# Generated 2900 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.027594s, Avg: 0.000001903s/op
# 2-3 - Search: 0.012867s, Avg: 0.000001775s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.027790s, Avg: 0.000001917s/op
# LLRB - Search: 0.004130s, Avg: 0.000000570s/op
# Generated 2900 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.029039s, Avg: 0.000002003s/op
# 2-3 - Search: 0.010475s, Avg: 0.000001445s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.026599s, Avg: 0.000001834s/op
# LLRB - Search: 0.004445s, Avg: 0.000000613s/op
#
# === random, size=3100 ===
# Generated 3100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.033500s, Avg: 0.000002161s/op
# 2-3 - Search: 0.009853s, Avg: 0.000001271s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.028750s, Avg: 0.000001855s/op
# LLRB - Search: 0.006322s, Avg: 0.000000816s/op
# Generated 3100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.030903s, Avg: 0.000001994s/op
# 2-3 - Search: 0.008728s, Avg: 0.000001126s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.030024s, Avg: 0.000001937s/op
# LLRB - Search: 0.004523s, Avg: 0.000000584s/op
# Generated 3100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.027432s, Avg: 0.000001770s/op
# 2-3 - Search: 0.009895s, Avg: 0.000001277s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.028397s, Avg: 0.000001832s/op
# LLRB - Search: 0.003641s, Avg: 0.000000470s/op
#
# === random, size=3300 ===
# Generated 3300 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.031463s, Avg: 0.000001907s/op
# 2-3 - Search: 0.011339s, Avg: 0.000001374s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.031697s, Avg: 0.000001921s/op
# LLRB - Search: 0.005242s, Avg: 0.000000635s/op
# Generated 3300 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.033190s, Avg: 0.000002012s/op
# 2-3 - Search: 0.011727s, Avg: 0.000001422s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.033936s, Avg: 0.000002057s/op
# LLRB - Search: 0.004902s, Avg: 0.000000594s/op
# Generated 3300 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.031446s, Avg: 0.000001906s/op
# 2-3 - Search: 0.010965s, Avg: 0.000001329s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.029759s, Avg: 0.000001804s/op
# LLRB - Search: 0.003950s, Avg: 0.000000479s/op
#
# === random, size=3500 ===
# Generated 3500 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.031716s, Avg: 0.000001812s/op
# 2-3 - Search: 0.011526s, Avg: 0.000001317s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.033540s, Avg: 0.000001917s/op
# LLRB - Search: 0.004459s, Avg: 0.000000510s/op
# Generated 3500 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.034224s, Avg: 0.000001956s/op
# 2-3 - Search: 0.011691s, Avg: 0.000001336s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.031353s, Avg: 0.000001792s/op
# LLRB - Search: 0.004362s, Avg: 0.000000499s/op
# Generated 3500 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.033648s, Avg: 0.000001923s/op
# 2-3 - Search: 0.012474s, Avg: 0.000001426s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.034154s, Avg: 0.000001952s/op
# LLRB - Search: 0.004795s, Avg: 0.000000548s/op
#
# === random, size=3700 ===
# Generated 3700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.033683s, Avg: 0.000001821s/op
# 2-3 - Search: 0.012003s, Avg: 0.000001298s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.033744s, Avg: 0.000001824s/op
# LLRB - Search: 0.004441s, Avg: 0.000000480s/op
# Generated 3700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.032538s, Avg: 0.000001759s/op
# 2-3 - Search: 0.012480s, Avg: 0.000001349s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.036186s, Avg: 0.000001956s/op
# LLRB - Search: 0.005471s, Avg: 0.000000591s/op
# Generated 3700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.033139s, Avg: 0.000001791s/op
# 2-3 - Search: 0.012042s, Avg: 0.000001302s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.032415s, Avg: 0.000001752s/op
# LLRB - Search: 0.005302s, Avg: 0.000000573s/op
#
# === random, size=3900 ===
# Generated 3900 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.037899s, Avg: 0.000001944s/op
# 2-3 - Search: 0.012492s, Avg: 0.000001281s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.036809s, Avg: 0.000001888s/op
# LLRB - Search: 0.005580s, Avg: 0.000000572s/op
# Generated 3900 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.038175s, Avg: 0.000001958s/op
# 2-3 - Search: 0.013247s, Avg: 0.000001359s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.038455s, Avg: 0.000001972s/op
# LLRB - Search: 0.005068s, Avg: 0.000000520s/op
# Generated 3900 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.036509s, Avg: 0.000001872s/op
# 2-3 - Search: 0.013126s, Avg: 0.000001346s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.037485s, Avg: 0.000001922s/op
# LLRB - Search: 0.005524s, Avg: 0.000000567s/op
#
# === random, size=4100 ===
# Generated 4100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.039385s, Avg: 0.000001921s/op
# 2-3 - Search: 0.013733s, Avg: 0.000001340s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.037313s, Avg: 0.000001820s/op
# LLRB - Search: 0.005303s, Avg: 0.000000517s/op
# Generated 4100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.040476s, Avg: 0.000001974s/op
# 2-3 - Search: 0.015153s, Avg: 0.000001478s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.037863s, Avg: 0.000001847s/op
# LLRB - Search: 0.006320s, Avg: 0.000000617s/op
# Generated 4100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.042070s, Avg: 0.000002052s/op
# 2-3 - Search: 0.014085s, Avg: 0.000001374s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.040181s, Avg: 0.000001960s/op
# LLRB - Search: 0.005826s, Avg: 0.000000568s/op
#
# === random, size=4300 ===
# Generated 4300 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.038758s, Avg: 0.000001803s/op
# 2-3 - Search: 0.014414s, Avg: 0.000001341s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.039304s, Avg: 0.000001828s/op
# LLRB - Search: 0.006056s, Avg: 0.000000563s/op
# Generated 4300 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.040357s, Avg: 0.000001877s/op
# 2-3 - Search: 0.013510s, Avg: 0.000001257s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.038794s, Avg: 0.000001804s/op
# LLRB - Search: 0.006002s, Avg: 0.000000558s/op
# Generated 4300 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.039547s, Avg: 0.000001839s/op
# 2-3 - Search: 0.013510s, Avg: 0.000001257s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.039715s, Avg: 0.000001847s/op
# LLRB - Search: 0.005567s, Avg: 0.000000518s/op
#
# === random, size=4500 ===
# Generated 4500 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.040603s, Avg: 0.000001805s/op
# 2-3 - Search: 0.015059s, Avg: 0.000001339s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.042368s, Avg: 0.000001883s/op
# LLRB - Search: 0.006758s, Avg: 0.000000601s/op
# Generated 4500 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.040937s, Avg: 0.000001819s/op
# 2-3 - Search: 0.015414s, Avg: 0.000001370s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.041367s, Avg: 0.000001839s/op
# LLRB - Search: 0.005979s, Avg: 0.000000531s/op
# Generated 4500 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.043471s, Avg: 0.000001932s/op
# 2-3 - Search: 0.015223s, Avg: 0.000001353s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.040390s, Avg: 0.000001795s/op
# LLRB - Search: 0.006071s, Avg: 0.000000540s/op
#
# === random, size=4700 ===
# Generated 4700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.041861s, Avg: 0.000001781s/op
# 2-3 - Search: 0.015504s, Avg: 0.000001319s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.043121s, Avg: 0.000001835s/op
# LLRB - Search: 0.006995s, Avg: 0.000000595s/op
# Generated 4700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.043499s, Avg: 0.000001851s/op
# 2-3 - Search: 0.015423s, Avg: 0.000001313s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.042431s, Avg: 0.000001806s/op
# LLRB - Search: 0.007190s, Avg: 0.000000612s/op
# Generated 4700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.044180s, Avg: 0.000001880s/op
# 2-3 - Search: 0.015480s, Avg: 0.000001317s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.042876s, Avg: 0.000001824s/op
# LLRB - Search: 0.005924s, Avg: 0.000000504s/op
#
# === random, size=4900 ===
# Generated 4900 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.043739s, Avg: 0.000001785s/op
# 2-3 - Search: 0.015489s, Avg: 0.000001264s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.045435s, Avg: 0.000001854s/op
# LLRB - Search: 0.006691s, Avg: 0.000000546s/op
# Generated 4900 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.045978s, Avg: 0.000001877s/op
# 2-3 - Search: 0.016134s, Avg: 0.000001317s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.045757s, Avg: 0.000001868s/op
# LLRB - Search: 0.006436s, Avg: 0.000000525s/op
# Generated 4900 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.043250s, Avg: 0.000001765s/op
# 2-3 - Search: 0.017814s, Avg: 0.000001454s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.048163s, Avg: 0.000001966s/op
# LLRB - Search: 0.007535s, Avg: 0.000000615s/op
#
# === random, size=10000 ===
# Generated 10000 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.105232s, Avg: 0.000002105s/op
# 2-3 - Search: 0.037466s, Avg: 0.000001499s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.102024s, Avg: 0.000002040s/op
# LLRB - Search: 0.014471s, Avg: 0.000000579s/op
# Generated 10000 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.101357s, Avg: 0.000002027s/op
# 2-3 - Search: 0.037940s, Avg: 0.000001518s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.102043s, Avg: 0.000002041s/op
# LLRB - Search: 0.014357s, Avg: 0.000000574s/op
# Generated 10000 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.100740s, Avg: 0.000002015s/op
# 2-3 - Search: 0.037442s, Avg: 0.000001498s/op
# Testing LLRB
# LLRB - Tree height after insertion: 19
# LLRB - Insert: 0.103300s, Avg: 0.000002066s/op
# LLRB - Search: 0.014770s, Avg: 0.000000591s/op
#
# === sorted, size=0 ===
# Generated 0 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 0 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 0 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000000s, Avg: 0.000000000s/op
# LLRB - Search: 0.000000s, Avg: 0.000000000s/op
#
# === sorted, size=1 ===
# Generated 1 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 1
# 2-3 - Insert: 0.000007s, Avg: 0.000001480s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000002s, Avg: 0.000000320s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 1 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 1
# 2-3 - Insert: 0.000005s, Avg: 0.000001040s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000002s, Avg: 0.000000320s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 1 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 1
# 2-3 - Insert: 0.000004s, Avg: 0.000000800s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000001s, Avg: 0.000000260s/op
# LLRB - Search: 0.000000s, Avg: 0.000000000s/op
#
# === sorted, size=10 ===
# Generated 10 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000052s, Avg: 0.000001048s/op
# 2-3 - Search: 0.000011s, Avg: 0.000000432s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000021s, Avg: 0.000000418s/op
# LLRB - Search: 0.000005s, Avg: 0.000000196s/op
# Generated 10 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000046s, Avg: 0.000000920s/op
# 2-3 - Search: 0.000010s, Avg: 0.000000416s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000020s, Avg: 0.000000404s/op
# LLRB - Search: 0.000004s, Avg: 0.000000180s/op
# Generated 10 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000048s, Avg: 0.000000960s/op
# 2-3 - Search: 0.000008s, Avg: 0.000000336s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000020s, Avg: 0.000000402s/op
# LLRB - Search: 0.000004s, Avg: 0.000000172s/op
#
# === sorted, size=50 ===
# Generated 50 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000266s, Avg: 0.000001064s/op
# 2-3 - Search: 0.000057s, Avg: 0.000000460s/op
# Testing LLRB
# LLRB - Tree height after insertion: 6
# LLRB - Insert: 0.000177s, Avg: 0.000000706s/op
# LLRB - Search: 0.000028s, Avg: 0.000000227s/op
# Generated 50 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000259s, Avg: 0.000001037s/op
# 2-3 - Search: 0.000082s, Avg: 0.000000659s/op
# Testing LLRB
# LLRB - Tree height after insertion: 6
# LLRB - Insert: 0.000200s, Avg: 0.000000799s/op
# LLRB - Search: 0.000034s, Avg: 0.000000274s/op
# Generated 50 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000282s, Avg: 0.000001126s/op
# 2-3 - Search: 0.000066s, Avg: 0.000000530s/op
# Testing LLRB
# LLRB - Tree height after insertion: 6
# LLRB - Insert: 0.000175s, Avg: 0.000000701s/op
# LLRB - Search: 0.000031s, Avg: 0.000000246s/op
#
# === sorted, size=100 ===
# Generated 100 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.000596s, Avg: 0.000001193s/op
# 2-3 - Search: 0.000156s, Avg: 0.000000626s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.000410s, Avg: 0.000000820s/op
# LLRB - Search: 0.000078s, Avg: 0.000000312s/op
# Generated 100 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.000580s, Avg: 0.000001159s/op
# 2-3 - Search: 0.000219s, Avg: 0.000000876s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.000440s, Avg: 0.000000881s/op
# LLRB - Search: 0.000074s, Avg: 0.000000296s/op
# Generated 100 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.000618s, Avg: 0.000001236s/op
# 2-3 - Search: 0.000148s, Avg: 0.000000594s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.000388s, Avg: 0.000000777s/op
# LLRB - Search: 0.000068s, Avg: 0.000000270s/op
#
# === sorted, size=300 ===
# Generated 300 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.001952s, Avg: 0.000001302s/op
# 2-3 - Search: 0.000615s, Avg: 0.000000820s/op
# Testing LLRB
# LLRB - Tree height after insertion: 9
# LLRB - Insert: 0.001445s, Avg: 0.000000963s/op
# LLRB - Search: 0.000241s, Avg: 0.000000321s/op
# Generated 300 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.002412s, Avg: 0.000001608s/op
# 2-3 - Search: 0.000649s, Avg: 0.000000865s/op
# Testing LLRB
# LLRB - Tree height after insertion: 9
# LLRB - Insert: 0.001654s, Avg: 0.000001102s/op
# LLRB - Search: 0.000264s, Avg: 0.000000352s/op
# Generated 300 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.002139s, Avg: 0.000001426s/op
# 2-3 - Search: 0.000682s, Avg: 0.000000909s/op
# Testing LLRB
# LLRB - Tree height after insertion: 9
# LLRB - Insert: 0.001553s, Avg: 0.000001035s/op
# LLRB - Search: 0.000280s, Avg: 0.000000374s/op
#
# === sorted, size=500 ===
# Generated 500 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.004123s, Avg: 0.000001649s/op
# 2-3 - Search: 0.001216s, Avg: 0.000000973s/op
# Testing LLRB
# LLRB - Tree height after insertion: 9
# LLRB - Insert: 0.002777s, Avg: 0.000001111s/op
# LLRB - Search: 0.000440s, Avg: 0.000000352s/op
# Generated 500 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.003443s, Avg: 0.000001377s/op
# 2-3 - Search: 0.001071s, Avg: 0.000000857s/op
# Testing LLRB
# LLRB - Tree height after insertion: 9
# LLRB - Insert: 0.003217s, Avg: 0.000001287s/op
# LLRB - Search: 0.000433s, Avg: 0.000000347s/op
# Generated 500 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.003397s, Avg: 0.000001359s/op
# 2-3 - Search: 0.001089s, Avg: 0.000000871s/op
# Testing LLRB
# LLRB - Tree height after insertion: 9
# LLRB - Insert: 0.002792s, Avg: 0.000001117s/op
# LLRB - Search: 0.000437s, Avg: 0.000000349s/op
#
# === sorted, size=700 ===
# Generated 700 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.005122s, Avg: 0.000001464s/op
# 2-3 - Search: 0.001771s, Avg: 0.000001012s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.004968s, Avg: 0.000001419s/op
# LLRB - Search: 0.000675s, Avg: 0.000000385s/op
# Generated 700 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.005130s, Avg: 0.000001466s/op
# 2-3 - Search: 0.001699s, Avg: 0.000000971s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.005184s, Avg: 0.000001481s/op
# LLRB - Search: 0.000657s, Avg: 0.000000375s/op
# Generated 700 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.005006s, Avg: 0.000001430s/op
# 2-3 - Search: 0.001674s, Avg: 0.000000956s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.004564s, Avg: 0.000001304s/op
# LLRB - Search: 0.000655s, Avg: 0.000000375s/op
#
# === sorted, size=900 ===
# Generated 900 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.007208s, Avg: 0.000001602s/op
# 2-3 - Search: 0.002294s, Avg: 0.000001020s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.005493s, Avg: 0.000001221s/op
# LLRB - Search: 0.000938s, Avg: 0.000000417s/op
# Generated 900 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.007426s, Avg: 0.000001650s/op
# 2-3 - Search: 0.002186s, Avg: 0.000000972s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.006658s, Avg: 0.000001480s/op
# LLRB - Search: 0.000884s, Avg: 0.000000393s/op
# Generated 900 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.007098s, Avg: 0.000001577s/op
# 2-3 - Search: 0.002623s, Avg: 0.000001166s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.005571s, Avg: 0.000001238s/op
# LLRB - Search: 0.000959s, Avg: 0.000000426s/op
#
# === sorted, size=1100 ===
# Generated 1100 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.008840s, Avg: 0.000001607s/op
# 2-3 - Search: 0.002877s, Avg: 0.000001046s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.007499s, Avg: 0.000001363s/op
# LLRB - Search: 0.001156s, Avg: 0.000000420s/op
# Generated 1100 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.009380s, Avg: 0.000001705s/op
# 2-3 - Search: 0.002958s, Avg: 0.000001076s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.007104s, Avg: 0.000001292s/op
# LLRB - Search: 0.001164s, Avg: 0.000000423s/op
# Generated 1100 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.009129s, Avg: 0.000001660s/op
# 2-3 - Search: 0.003130s, Avg: 0.000001138s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.007088s, Avg: 0.000001289s/op
# LLRB - Search: 0.001196s, Avg: 0.000000435s/op
#
# === sorted, size=1300 ===
# Generated 1300 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.011272s, Avg: 0.000001734s/op
# 2-3 - Search: 0.003642s, Avg: 0.000001121s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.009287s, Avg: 0.000001429s/op
# LLRB - Search: 0.001454s, Avg: 0.000000447s/op
# Generated 1300 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.011504s, Avg: 0.000001770s/op
# 2-3 - Search: 0.003726s, Avg: 0.000001147s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.009039s, Avg: 0.000001391s/op
# LLRB - Search: 0.001501s, Avg: 0.000000462s/op
# Generated 1300 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.010503s, Avg: 0.000001616s/op
# 2-3 - Search: 0.003844s, Avg: 0.000001183s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.008909s, Avg: 0.000001371s/op
# LLRB - Search: 0.001483s, Avg: 0.000000456s/op
#
# === sorted, size=1500 ===
# Generated 1500 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.012944s, Avg: 0.000001726s/op
# 2-3 - Search: 0.004065s, Avg: 0.000001084s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.010349s, Avg: 0.000001380s/op
# LLRB - Search: 0.001707s, Avg: 0.000000455s/op
# Generated 1500 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.013113s, Avg: 0.000001748s/op
# 2-3 - Search: 0.004605s, Avg: 0.000001228s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.010041s, Avg: 0.000001339s/op
# LLRB - Search: 0.001646s, Avg: 0.000000439s/op
# Generated 1500 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.012477s, Avg: 0.000001664s/op
# 2-3 - Search: 0.004146s, Avg: 0.000001106s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.010876s, Avg: 0.000001450s/op
# LLRB - Search: 0.001657s, Avg: 0.000000442s/op
#
# === sorted, size=1700 ===
# Generated 1700 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.014558s, Avg: 0.000001713s/op
# 2-3 - Search: 0.004730s, Avg: 0.000001113s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.012520s, Avg: 0.000001473s/op
# LLRB - Search: 0.001977s, Avg: 0.000000465s/op
# Generated 1700 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.014397s, Avg: 0.000001694s/op
# 2-3 - Search: 0.004552s, Avg: 0.000001071s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.012831s, Avg: 0.000001510s/op
# LLRB - Search: 0.001822s, Avg: 0.000000429s/op
# Generated 1700 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.015261s, Avg: 0.000001795s/op
# 2-3 - Search: 0.004796s, Avg: 0.000001128s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.012407s, Avg: 0.000001460s/op
# LLRB - Search: 0.001953s, Avg: 0.000000459s/op
#
# === sorted, size=1900 ===
# Generated 1900 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.017132s, Avg: 0.000001803s/op
# 2-3 - Search: 0.005218s, Avg: 0.000001098s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.013444s, Avg: 0.000001415s/op
# LLRB - Search: 0.002861s, Avg: 0.000000602s/op
# Generated 1900 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.016033s, Avg: 0.000001688s/op
# 2-3 - Search: 0.005679s, Avg: 0.000001196s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.013747s, Avg: 0.000001447s/op
# LLRB - Search: 0.002260s, Avg: 0.000000476s/op
# Generated 1900 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.016071s, Avg: 0.000001692s/op
# 2-3 - Search: 0.005572s, Avg: 0.000001173s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.013465s, Avg: 0.000001417s/op
# LLRB - Search: 0.002047s, Avg: 0.000000431s/op
#
# === sorted, size=2100 ===
# Generated 2100 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.018966s, Avg: 0.000001806s/op
# 2-3 - Search: 0.006676s, Avg: 0.000001272s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.015342s, Avg: 0.000001461s/op
# LLRB - Search: 0.002333s, Avg: 0.000000444s/op
# Generated 2100 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.023548s, Avg: 0.000002243s/op
# 2-3 - Search: 0.007772s, Avg: 0.000001480s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.015268s, Avg: 0.000001454s/op
# LLRB - Search: 0.002646s, Avg: 0.000000504s/op
# Generated 2100 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.018007s, Avg: 0.000001715s/op
# 2-3 - Search: 0.006580s, Avg: 0.000001253s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.014566s, Avg: 0.000001387s/op
# LLRB - Search: 0.002341s, Avg: 0.000000446s/op
#
# === sorted, size=2300 ===
# Generated 2300 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.019977s, Avg: 0.000001737s/op
# 2-3 - Search: 0.007587s, Avg: 0.000001319s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.016783s, Avg: 0.000001459s/op
# LLRB - Search: 0.002870s, Avg: 0.000000499s/op
# Generated 2300 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.020898s, Avg: 0.000001817s/op
# 2-3 - Search: 0.007907s, Avg: 0.000001375s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.016524s, Avg: 0.000001437s/op
# LLRB - Search: 0.003028s, Avg: 0.000000527s/op
# Generated 2300 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.021363s, Avg: 0.000001858s/op
# 2-3 - Search: 0.007069s, Avg: 0.000001229s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.016770s, Avg: 0.000001458s/op
# LLRB - Search: 0.002668s, Avg: 0.000000464s/op
#
# === sorted, size=2500 ===
# Generated 2500 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.021668s, Avg: 0.000001733s/op
# 2-3 - Search: 0.007898s, Avg: 0.000001264s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.017925s, Avg: 0.000001434s/op
# LLRB - Search: 0.002970s, Avg: 0.000000475s/op
# Generated 2500 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.022404s, Avg: 0.000001792s/op
# 2-3 - Search: 0.008259s, Avg: 0.000001321s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.018959s, Avg: 0.000001517s/op
# LLRB - Search: 0.002805s, Avg: 0.000000449s/op
# Generated 2500 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.022918s, Avg: 0.000001833s/op
# 2-3 - Search: 0.008997s, Avg: 0.000001439s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.018440s, Avg: 0.000001475s/op
# LLRB - Search: 0.002997s, Avg: 0.000000480s/op
#
# === sorted, size=2700 ===
# Generated 2700 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.023646s, Avg: 0.000001752s/op
# 2-3 - Search: 0.008633s, Avg: 0.000001279s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.021111s, Avg: 0.000001564s/op
# LLRB - Search: 0.003969s, Avg: 0.000000588s/op
# Generated 2700 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.023848s, Avg: 0.000001767s/op
# 2-3 - Search: 0.008389s, Avg: 0.000001243s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.020139s, Avg: 0.000001492s/op
# LLRB - Search: 0.003769s, Avg: 0.000000558s/op
# Generated 2700 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.023694s, Avg: 0.000001755s/op
# 2-3 - Search: 0.008123s, Avg: 0.000001203s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.020356s, Avg: 0.000001508s/op
# LLRB - Search: 0.004709s, Avg: 0.000000698s/op
#
# === sorted, size=2900 ===
# Generated 2900 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.028861s, Avg: 0.000001990s/op
# 2-3 - Search: 0.009607s, Avg: 0.000001325s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.021653s, Avg: 0.000001493s/op
# LLRB - Search: 0.003614s, Avg: 0.000000498s/op
# Generated 2900 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.025471s, Avg: 0.000001757s/op
# 2-3 - Search: 0.009350s, Avg: 0.000001290s/op
# Testing LLRB
# ...
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.017010s, Avg: 0.000001620s/op
# 2-3 - Search: 0.006485s, Avg: 0.000001235s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.015871s, Avg: 0.000001511s/op
# LLRB - Search: 0.002360s, Avg: 0.000000450s/op
# Generated 2100 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.017186s, Avg: 0.000001637s/op
# 2-3 - Search: 0.006792s, Avg: 0.000001294s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.015593s, Avg: 0.000001485s/op
# LLRB - Search: 0.002496s, Avg: 0.000000475s/op
#
# === reverse_sorted, size=2300 ===
# Generated 2300 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.019381s, Avg: 0.000001685s/op
# 2-3 - Search: 0.007681s, Avg: 0.000001336s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.017400s, Avg: 0.000001513s/op
# LLRB - Search: 0.002688s, Avg: 0.000000467s/op
# Generated 2300 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.019410s, Avg: 0.000001688s/op
# 2-3 - Search: 0.007888s, Avg: 0.000001372s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.017883s, Avg: 0.000001555s/op
# LLRB - Search: 0.002608s, Avg: 0.000000454s/op
# Generated 2300 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.018328s, Avg: 0.000001594s/op
# 2-3 - Search: 0.006924s, Avg: 0.000001204s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.017665s, Avg: 0.000001536s/op
# LLRB - Search: 0.002517s, Avg: 0.000000438s/op
#
# === reverse_sorted, size=2500 ===
# Generated 2500 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.021124s, Avg: 0.000001690s/op
# 2-3 - Search: 0.007258s, Avg: 0.000001161s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.020507s, Avg: 0.000001641s/op
# LLRB - Search: 0.003116s, Avg: 0.000000499s/op
# Generated 2500 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.021330s, Avg: 0.000001706s/op
# 2-3 - Search: 0.007724s, Avg: 0.000001236s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.019283s, Avg: 0.000001543s/op
# LLRB - Search: 0.002739s, Avg: 0.000000438s/op
# Generated 2500 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.021289s, Avg: 0.000001703s/op
# 2-3 - Search: 0.007721s, Avg: 0.000001235s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.019412s, Avg: 0.000001553s/op
# LLRB - Search: 0.003515s, Avg: 0.000000562s/op
#
# === reverse_sorted, size=2700 ===
# Generated 2700 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.021963s, Avg: 0.000001627s/op
# 2-3 - Search: 0.008730s, Avg: 0.000001293s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.022674s, Avg: 0.000001680s/op
# LLRB - Search: 0.003033s, Avg: 0.000000449s/op
# Generated 2700 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.022565s, Avg: 0.000001671s/op
# 2-3 - Search: 0.008148s, Avg: 0.000001207s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.020735s, Avg: 0.000001536s/op
# LLRB - Search: 0.003247s, Avg: 0.000000481s/op
# Generated 2700 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.023131s, Avg: 0.000001713s/op
# 2-3 - Search: 0.008772s, Avg: 0.000001300s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.020684s, Avg: 0.000001532s/op
# LLRB - Search: 0.003243s, Avg: 0.000000480s/op
#
# === reverse_sorted, size=2900 ===
# Generated 2900 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.023799s, Avg: 0.000001641s/op
# 2-3 - Search: 0.009942s, Avg: 0.000001371s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.024077s, Avg: 0.000001660s/op
# LLRB - Search: 0.003820s, Avg: 0.000000527s/op
# Generated 2900 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.028915s, Avg: 0.000001994s/op
# 2-3 - Search: 0.010984s, Avg: 0.000001515s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.024314s, Avg: 0.000001677s/op
# LLRB - Search: 0.003812s, Avg: 0.000000526s/op
# Generated 2900 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.024354s, Avg: 0.000001680s/op
# 2-3 - Search: 0.008903s, Avg: 0.000001228s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.023654s, Avg: 0.000001631s/op
# LLRB - Search: 0.003663s, Avg: 0.000000505s/op
#
# === reverse_sorted, size=3100 ===
# Generated 3100 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.025362s, Avg: 0.000001636s/op
# 2-3 - Search: 0.009917s, Avg: 0.000001280s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.025632s, Avg: 0.000001654s/op
# LLRB - Search: 0.003532s, Avg: 0.000000456s/op
# Generated 3100 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.027348s, Avg: 0.000001764s/op
# 2-3 - Search: 0.009750s, Avg: 0.000001258s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.025252s, Avg: 0.000001629s/op
# LLRB - Search: 0.003947s, Avg: 0.000000509s/op
# Generated 3100 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.025735s, Avg: 0.000001660s/op
# 2-3 - Search: 0.009560s, Avg: 0.000001234s/op
# Testing LLRB
# LLRB - Tree height after insertion: 16
# LLRB - Insert: 0.024877s, Avg: 0.000001605s/op
# LLRB - Search: 0.003714s, Avg: 0.000000479s/op
#
# === reverse_sorted, size=3300 ===
# Generated 3300 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.026369s, Avg: 0.000001598s/op
# 2-3 - Search: 0.010152s, Avg: 0.000001231s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.028302s, Avg: 0.000001715s/op
# LLRB - Search: 0.003920s, Avg: 0.000000475s/op
# Generated 3300 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.028417s, Avg: 0.000001722s/op
# 2-3 - Search: 0.010756s, Avg: 0.000001304s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.027646s, Avg: 0.000001676s/op
# LLRB - Search: 0.004859s, Avg: 0.000000589s/op
# Generated 3300 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.027346s, Avg: 0.000001657s/op
# 2-3 - Search: 0.010752s, Avg: 0.000001303s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.028552s, Avg: 0.000001730s/op
# LLRB - Search: 0.004406s, Avg: 0.000000534s/op
#
# === reverse_sorted, size=3500 ===
# Generated 3500 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.029681s, Avg: 0.000001696s/op
# 2-3 - Search: 0.012442s, Avg: 0.000001422s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.030825s, Avg: 0.000001761s/op
# LLRB - Search: 0.004070s, Avg: 0.000000465s/op
# Generated 3500 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.029110s, Avg: 0.000001663s/op
# 2-3 - Search: 0.011245s, Avg: 0.000001285s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.029857s, Avg: 0.000001706s/op
# LLRB - Search: 0.004943s, Avg: 0.000000565s/op
# Generated 3500 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.029952s, Avg: 0.000001712s/op
# 2-3 - Search: 0.011731s, Avg: 0.000001341s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.029312s, Avg: 0.000001675s/op
# LLRB - Search: 0.004819s, Avg: 0.000000551s/op
#
# === reverse_sorted, size=3700 ===
# Generated 3700 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.030948s, Avg: 0.000001673s/op
# 2-3 - Search: 0.012815s, Avg: 0.000001385s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.031984s, Avg: 0.000001729s/op
# LLRB - Search: 0.005344s, Avg: 0.000000578s/op
# Generated 3700 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.031464s, Avg: 0.000001701s/op
# 2-3 - Search: 0.012495s, Avg: 0.000001351s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.032053s, Avg: 0.000001733s/op
# LLRB - Search: 0.004482s, Avg: 0.000000485s/op
# Generated 3700 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.030832s, Avg: 0.000001667s/op
# 2-3 - Search: 0.013318s, Avg: 0.000001440s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.032042s, Avg: 0.000001732s/op
# LLRB - Search: 0.004640s, Avg: 0.000000502s/op
#
# === reverse_sorted, size=3900 ===
# Generated 3900 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.033902s, Avg: 0.000001739s/op
# 2-3 - Search: 0.013609s, Avg: 0.000001396s/op
# Testing LLRB
# LLRB - Tree height after insertion: 19
# LLRB - Insert: 0.033863s, Avg: 0.000001737s/op
# LLRB - Search: 0.005605s, Avg: 0.000000575s/op
# Generated 3900 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.032897s, Avg: 0.000001687s/op
# 2-3 - Search: 0.013055s, Avg: 0.000001339s/op
# Testing LLRB
# LLRB - Tree height after insertion: 19
# LLRB - Insert: 0.033865s, Avg: 0.000001737s/op
# LLRB - Search: 0.005185s, Avg: 0.000000532s/op
# Generated 3900 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.032925s, Avg: 0.000001688s/op
# 2-3 - Search: 0.013666s, Avg: 0.000001402s/op
# Testing LLRB
# LLRB - Tree height after insertion: 19
# LLRB - Insert: 0.035122s, Avg: 0.000001801s/op
# LLRB - Search: 0.005122s, Avg: 0.000000525s/op
#
# === reverse_sorted, size=4100 ===
# Generated 4100 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 12
# 2-3 - Insert: 0.035939s, Avg: 0.000001753s/op
# 2-3 - Search: 0.015687s, Avg: 0.000001530s/op
# Testing LLRB
# LLRB - Tree height after insertion: 14
# LLRB - Insert: 0.034496s, Avg: 0.000001683s/op
# LLRB - Search: 0.005105s, Avg: 0.000000498s/op
# Generated 4100 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 12
# 2-3 - Insert: 0.035677s, Avg: 0.000001740s/op
# 2-3 - Search: 0.014196s, Avg: 0.000001385s/op
# Testing LLRB
# LLRB - Tree height after insertion: 14
# LLRB - Insert: 0.033450s, Avg: 0.000001632s/op
# LLRB - Search: 0.004943s, Avg: 0.000000482s/op
# Generated 4100 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 12
# 2-3 - Insert: 0.036405s, Avg: 0.000001776s/op
# 2-3 - Search: 0.014430s, Avg: 0.000001408s/op
# Testing LLRB
# LLRB - Tree height after insertion: 14
# LLRB - Insert: 0.034741s, Avg: 0.000001695s/op
# LLRB - Search: 0.005241s, Avg: 0.000000511s/op
#
# === reverse_sorted, size=4300 ===
# Generated 4300 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 12
# 2-3 - Insert: 0.037182s, Avg: 0.000001729s/op
# 2-3 - Search: 0.015943s, Avg: 0.000001483s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.036686s, Avg: 0.000001706s/op
# LLRB - Search: 0.005686s, Avg: 0.000000529s/op
# Generated 4300 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 12
# 2-3 - Insert: 0.038384s, Avg: 0.000001785s/op
# 2-3 - Search: 0.016874s, Avg: 0.000001570s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.035438s, Avg: 0.000001648s/op
# LLRB - Search: 0.006077s, Avg: 0.000000565s/op
# Generated 4300 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 12
# 2-3 - Insert: 0.036607s, Avg: 0.000001703s/op
# 2-3 - Search: 0.014886s, Avg: 0.000001385s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.035940s, Avg: 0.000001672s/op
# LLRB - Search: 0.006013s, Avg: 0.000000559s/op
#
# === reverse_sorted, size=4500 ===
# Generated 4500 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 12
# 2-3 - Insert: 0.040710s, Avg: 0.000001809s/op
# 2-3 - Search: 0.015949s, Avg: 0.000001418s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.038664s, Avg: 0.000001718s/op
# LLRB - Search: 0.005498s, Avg: 0.000000489s/op
# Generated 4500 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 12
# 2-3 - Insert: 0.038307s, Avg: 0.000001703s/op
# 2-3 - Search: 0.016047s, Avg: 0.000001426s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.038446s, Avg: 0.000001709s/op
# LLRB - Search: 0.007322s, Avg: 0.000000651s/op
# Generated 4500 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 12
# 2-3 - Insert: 0.040779s, Avg: 0.000001812s/op
# 2-3 - Search: 0.016027s, Avg: 0.000001425s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.038241s, Avg: 0.000001700s/op
# LLRB - Search: 0.006254s, Avg: 0.000000556s/op
#
# === reverse_sorted, size=4700 ===
# Generated 4700 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 12
# 2-3 - Insert: 0.040011s, Avg: 0.000001703s/op
# 2-3 - Search: 0.017092s, Avg: 0.000001455s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.040506s, Avg: 0.000001724s/op
# LLRB - Search: 0.005853s, Avg: 0.000000498s/op
# Generated 4700 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 12
# 2-3 - Insert: 0.041336s, Avg: 0.000001759s/op
# 2-3 - Search: 0.017420s, Avg: 0.000001483s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.039285s, Avg: 0.000001672s/op
# LLRB - Search: 0.006279s, Avg: 0.000000534s/op
# Generated 4700 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 12
# 2-3 - Insert: 0.041071s, Avg: 0.000001748s/op
# 2-3 - Search: 0.023072s, Avg: 0.000001964s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.040507s, Avg: 0.000001724s/op
# LLRB - Search: 0.006484s, Avg: 0.000000552s/op
#
# === reverse_sorted, size=4900 ===
# Generated 4900 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 12
# 2-3 - Insert: 0.041732s, Avg: 0.000001703s/op
# 2-3 - Search: 0.017927s, Avg: 0.000001463s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.041818s, Avg: 0.000001707s/op
# LLRB - Search: 0.006555s, Avg: 0.000000535s/op
# Generated 4900 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 12
# 2-3 - Insert: 0.044543s, Avg: 0.000001818s/op
# 2-3 - Search: 0.018146s, Avg: 0.000001481s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.041385s, Avg: 0.000001689s/op
# LLRB - Search: 0.006888s, Avg: 0.000000562s/op
# Generated 4900 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 12
# 2-3 - Insert: 0.042236s, Avg: 0.000001724s/op
# 2-3 - Search: 0.019574s, Avg: 0.000001598s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.041568s, Avg: 0.000001697s/op
# LLRB - Search: 0.006626s, Avg: 0.000000541s/op
#
# === reverse_sorted, size=10000 ===
# Generated 10000 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 13
# 2-3 - Insert: 0.094412s, Avg: 0.000001888s/op
# 2-3 - Search: 0.040594s, Avg: 0.000001624s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.094595s, Avg: 0.000001892s/op
# LLRB - Search: 0.014867s, Avg: 0.000000595s/op
# Generated 10000 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 13
# 2-3 - Insert: 0.091229s, Avg: 0.000001825s/op
# 2-3 - Search: 0.039649s, Avg: 0.000001586s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.097198s, Avg: 0.000001944s/op
# LLRB - Search: 0.014984s, Avg: 0.000000599s/op
# Generated 10000 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 13
# 2-3 - Insert: 0.092253s, Avg: 0.000001845s/op
# 2-3 - Search: 0.042860s, Avg: 0.000001714s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.092134s, Avg: 0.000001843s/op
# LLRB - Search: 0.014716s, Avg: 0.000000589s/op
