# %% [markdown]
# # COMP0005 - GROUP COURSEWORK
# # Experimental Evaluation of Search Data Structures and Algorithms

# %% [markdown]
# The cell below defines **AbstractSearchInterface**, an interface to support basic insert/search operations; you will need to implement this three times, to realise your three search data structures of choice among: (1) *2-3 Tree*, (2) *AVL Tree*, (3) *LLRB BST*; (4) *B-Tree*; and (5) *Scapegoat Tree*. <br><br>**Do NOT modify the next cell** - use the dedicated cells further below for your implementation instead. <br>

# %%
# DO NOT MODIFY THIS CELL

from abc import ABC, abstractmethod  

class AbstractSearchInterface(ABC):
    '''
    Abstract class to support search/insert operations (plus underlying data structure)
    
    '''
        
    @abstractmethod
    def insertElement(self, element):     
        '''
        Insert an element in a search tree
            Parameters:
                    element: string to be inserted in the search tree (string)

            Returns:
                    "True" after successful insertion, "False" if element is already present (bool)
        '''
        
        pass 
    

    @abstractmethod
    def searchElement(self, element):
        '''
        Search for an element in a search tree
            Parameters:
                    element: string to be searched in the search tree (string)

            Returns:
                    "True" if element is found, "False" otherwise (bool)
        '''

        pass

# %% [markdown]
# Use the cell below to define any auxiliary data structure and python function you may need. Leave the implementation of the main API to the next code cells instead.

# %%
# ADD AUXILIARY DATA STRUCTURE DEFINITIONS AND HELPER CODE HERE
class Node: 
    def __init__(self, element): 
        self.left = None
        self.right = None
        self.parent = None
        self.element = element
        
class Node1:
    def __init__(self):
        self.keys = []
        self.children = []

    def is_leaf(self):
        return len(self.children) == 0

    def insert_key(self, key):
        # Insert key into the keys list in sorted order
        index = 0
        while index < len(self.keys) and key > self.keys[index]:
            index += 1
        self.keys.insert(index, key)

    def split(self):
        # Split the node into two nodes and return the middle key
        mid_index = len(self.keys) // 2
        mid_key = self.keys[mid_index]

        left = Node1()
        left.keys = self.keys[:mid_index]

        right = Node1()
        right.keys = self.keys[mid_index + 1:]

        if not self.is_leaf():
            # Split the children accordingly
            left.children = self.children[:mid_index + 1]
            right.children = self.children[mid_index + 1:]

        return mid_key, left, right
        
class LLRBNode:
    def __init__(self, key, color, left=None, right=None):
        self.key = key
        self.color = color  # True indicates red, False indicates black
        self.left = left
        self.right = right

# %% [markdown]
# Use the cell below to implement the requested API by means of **2-3 Tree** (if among your chosen data structure).

# %%
class TwoThreeTree:
    def __init__(self):
        self.root = Node1()

    def searchElement(self, key):
        node = self.root
        while node:
            found = False
            for i in range(len(node.keys)):
                if key == node.keys[i]:
                    return True
                elif key < node.keys[i]:
                    if node.is_leaf():
                        return False
                    node = node.children[i]
                    found = True
                    break
            if not found:
                if node.is_leaf():
                    return False
                node = node.children[-1]
        return False

    def insertElement(self, key):
        split_result = self._insert(self.root, key)
        if split_result:
            # Root needs to split
            mid_key, left, right = split_result
            new_root = Node1()
            new_root.keys.append(mid_key)
            new_root.children.append(left)
            new_root.children.append(right)
            self.root = new_root

    def _insert(self, node, key):
        if node.is_leaf():
            node.insert_key(key)
            if len(node.keys) > 2:
                return node.split()
            return None
        else:
            # Find the appropriate child to insert
            child_index = 0
            while child_index < len(node.keys) and key >= node.keys[child_index]:
                child_index += 1

            split_result = self._insert(node.children[child_index], key)
            if split_result:
                mid_key, left, right = split_result

                # Insert the mid_key into current node
                insert_index = 0
                while insert_index < len(node.keys) and mid_key > node.keys[insert_index]:
                    insert_index += 1
                node.keys.insert(insert_index, mid_key)

                # Replace the child with left and right
                node.children.pop(child_index)
                node.children.insert(child_index, right)
                node.children.insert(child_index, left)

                if len(node.keys) > 2:
                    return node.split()
            return None
        
    def height(self):
        """Calculate the height of the 2-3 tree."""
        if not self.root.keys:  # if root null, height is 0
            return 0
        return self._height(self.root)

    def _height(self, node):
        """Helper method to recursively calculate height."""
        if node.is_leaf():
            return 1  
       
        return 1 + max(self._height(child) for child in node.children)

# %%
class AVLTree(AbstractSearchInterface):
        
    def insertElement(self, element):
        inserted = False
        # ADD YOUR CODE HERE
      
        
        return inserted
    
    

    def searchElement(self, element):     
        found = False
        # ADD YOUR CODE HERE

        
        return found

# %% [markdown]
# Use the cell below to implement the requested API by means of **LLRB BST** (if among your chosen data structure).

# %%
class LLRBTree:
    def __init__(self):
        self.root = None

    def is_red(self, node):
        return node is not None and node.color
    
    def _rotate_left(self, h:LLRBNode):
        x = h.right
        h.right = x.left
        x.left = h
        x.color = h.color
        h.color = True
        return x

    def _rotate_right(self, h):
        x = h.left
        h.left = x.right
        x.right = h
        x.color = h.color
        h.color = True
        return x

    def _flip_colors(self, h):
        h.color = not h.color
        if h.left:
            h.left.color = not h.left.color
        if h.right:
            h.right.color = not h.right.color

    def _insert(self, h, key):
        if h is None:
            return LLRBNode(key, True)
        if key == h.key:
            return h  # Ignore duplicates
        if key < h.key:
            h.left = self._insert(h.left, key)
        elif key > h.key:
            h.right = self._insert(h.right, key)
        if self.is_red(h.right) and not self.is_red(h.left):
            h = self._rotate_left(h)
        if self.is_red(h.left) and self.is_red(h.left.left):
            h = self._rotate_right(h)
        if self.is_red(h.left) and self.is_red(h.right):
            self._flip_colors(h)
        return h

    def insertElement(self, key):
        self.root = self._insert(self.root, key)
        self.root.color = False

    def searchElement(self, key):
        return self._search(self.root, key)

    def _search(self, node, key):
        if node is None:
            return False
        if key < node.key:
            return self._search(node.left, key)
        elif key > node.key:
            return self._search(node.right, key)
        else:
            return True
    
    def height(self):
        return self._height(self.root)

    def _height(self, node):
        if node is None:
            return 0
        return 1 + max(self._height(node.left), self._height(node.right))

# %% [markdown]
# Use the cell below to implement the requested API by means of **B-Tree** (if among your chosen data structure).

# %%
class BTree(AbstractSearchInterface):
        
    def insertElement(self, element):
        inserted = False
        # ADD YOUR CODE HERE
      
        
        return inserted
    
    

    def searchElement(self, element):     
        found = False
        # ADD YOUR CODE HERE

        
        return found

# %% [markdown]
# Use the cell below to implement the requested API by means of **Scapegoat Tree** (if among your chosen data structure).

# %%
import math
from collections import deque

class Node:
    def __init__(self, element):
        self.element = element
        self.left = None
        self.right = None
        self.parent = None
        self.size = 1

class ScapegoatTree:
    def __init__(self):
        self.totalSize = 0
        self.root = None

    def getSize(self, node):
        return node.size if node else 0

    def updateSize(self, node):
        if node:
            node.size = 1 + self.getSize(node.left) + self.getSize(node.right)

    def insertElement(self, element):
        newNode = Node(element)
        if self.root is None:
            self.root = newNode
            self.totalSize += 1
            return True

        currNode = self.root
        treeDepth = 0
        path = []

        while currNode:
            path.append(currNode)
            treeDepth += 1
            if newNode.element < currNode.element:
                currNode = currNode.left
            elif newNode.element > currNode.element:
                currNode = currNode.right
            else:
                #print("Element already in tree")
                return False
        
        newNode.parent = path[-1]
        if newNode.element < path[-1].element:
            path[-1].left = newNode
        else:
            path[-1].right = newNode
        
        self.totalSize += 1
        for node in path:
            self.updateSize(node)

        if treeDepth > math.log(self.totalSize, 1.5):
            parentNode = path[-1]
            while parentNode.parent and (3 * self.getSize(parentNode) <= 2 * self.getSize(parentNode.parent)):
                parentNode = parentNode.parent
            scapegoat = parentNode.parent or parentNode
            self.rebuild(scapegoat)

        return True

    def rebuild(self, scapegoat):
        def computeSize(node):
            if not node:
                return 0
            return 1 + computeSize(node.left) + computeSize(node.right)
        
        subtreeSize = computeSize(scapegoat)
        parentNode = scapegoat.parent
        array = [None] * subtreeSize
        actual_index = self.flattenSubtree(scapegoat, array, 0)
        if actual_index != subtreeSize:
            raise ValueError(f"Flattened {actual_index} nodes, expected {subtreeSize}")
        if parentNode is None:
            self.root = self.buildNewSubtree(array, 0, subtreeSize)
            self.root.parent = None
        elif parentNode.right == scapegoat:
            parentNode.right = self.buildNewSubtree(array, 0, subtreeSize)
            parentNode.right.parent = parentNode
        else:
            parentNode.left = self.buildNewSubtree(array, 0, subtreeSize)
            parentNode.left.parent = parentNode

    def buildNewSubtree(self, array, index, size):
        if size == 0:
            return None
        centre = size // 2
        node = array[index + centre]
        node.left = self.buildNewSubtree(array, index, centre)
        if node.left:
            node.left.parent = node
        node.right = self.buildNewSubtree(array, index + centre + 1, size - centre - 1)
        if node.right:
            node.right.parent = node
        self.updateSize(node)
        return node

    def flattenSubtree(self, node, array, index):
        if node is None:
            return index
        index = self.flattenSubtree(node.left, array, index)
        if index >= len(array):
            raise ValueError(f"Index {index} exceeds array length {len(array)}")
        array[index] = node
        index += 1
        index = self.flattenSubtree(node.right, array, index)
        return index

    def searchElement(self, element):
        currNode = self.root
        while currNode:
            if element < currNode.element:
                currNode = currNode.left
            elif element > currNode.element:
                currNode = currNode.right
            else:
                return True
        return False

    def height(self):
        return self._height(self.root)

    def _height(self, node):
        if node is None:
            return 0
        return 1 + max(self._height(node.left), self._height(node.right))

# %% [markdown]
# Use the cell below to implement the **synthetic data generator** needed by your experimental framework (be mindful of code readability and reusability).

# %%
import random
import string

class TestDataGenerator:
    def __init__(self, data_size=5000, string_length=8, distribution="random"):
        """
        Parameters
        ----------
        data_size : int
            Number of strings to generate (default 2000).
        string_length : int
            Length of each string (default 8).
        distribution : str
            'random', 'sorted', 'almost_sorted', 'repetitive', 'all_same', 'reverse_sorted'.
        """
        self.data_size = data_size
        self.string_length = string_length
        self.distribution = distribution
        self.alphabet = string.ascii_lowercase
        self._random_data = None  # 缓存随机生成的数组

    def _generate_random_strings(self):
        """Generate random strings with minimal collision checks."""
        data = []
        seen = set()
        for _ in range(self.data_size):
            while True:
                s = ''.join(random.choices(self.alphabet, k=self.string_length))
                if s not in seen:
                    seen.add(s)
                    data.append(s)
                    break
        return data

    def _ensure_random_data(self):
        """确保随机数据已生成并缓存"""
        if self._random_data is None:
            self._random_data = self._generate_random_strings()
        return self._random_data

    def generate_data(self):
        """Generate and return a list of strings based on the distribution."""
        # 所有分布都基于同一个随机数组
        random_data = self._ensure_random_data()

        if self.distribution == "random":
            return random_data.copy()  # 返回副本，避免修改原始数据
        elif self.distribution == "sorted":
            return sorted(random_data)
        elif self.distribution == "almost_sorted":
            return self._generate_almost_sorted_strings(random_data)
        elif self.distribution == "repetitive":
            return self._generate_repetitive_strings(random_data)
        elif self.distribution == "all_same":
            return self._generate_all_same_strings()
        elif self.distribution == "reverse_sorted":
            return sorted(random_data, reverse=True)
        else:
            return random_data.copy()

    def _generate_almost_sorted_strings(self, random_data):
        """Generate almost sorted strings by perturbing sorted random strings."""
        data = sorted(random_data)
        for _ in range(min(3, self.data_size // 2)):  # dynamically adjust swap times
            i, j = random.sample(range(self.data_size), 2)
            data[i], data[j] = data[j], data[i]
        return data

    def _generate_repetitive_strings(self, random_data):
        """生成具有一定重复性的唯一字符串，但限制重复度以保持测试意义"""
        unique_count = max(1, self.data_size // 10)  # 10% unique strings
        unique_strings = random_data[:unique_count]
        return [unique_strings[i % unique_count] for i in range(self.data_size)]

    def _generate_all_same_strings(self):
        """Generate a list where all strings are identical."""
        s = ''.join(random.choices(self.alphabet, k=self.string_length))
        return [s] * self.data_size

# Test
if __name__ == "__main__":
    gen = TestDataGenerator(data_size=5000, string_length=8, distribution="random")
    test = gen.generate_data()
    print(f"Generated {len(test)} strings, first 5: {test[:5]}")
# Out:
# Generated 5000 strings, first 5: ['avrtuxbk', 'utuycbfb', 'ewqqbnso', 'nsberulc', 'zllldybp']

# %% [markdown]
# Use the cell below to implement the requested **experimental framework** (be mindful of code readability and reusability).

# %%
import timeit

class ExperimentalFramework:
    def __init__(self, data_structures, data_generator, repeat=5):
        self.data_structures = data_structures
        self.data_generator = data_generator
        self.repeat = repeat
        self.results = {
            "total_insertion_time": {},
            "total_search_time": {},
            "avg_insertion_per_op": {},
            "avg_search_per_op": {},
           
        }

    def run_experiment(self, search_sample_size=None):
        data = self.data_generator.generate_data()
        total_strings = len(data)
        print(f"Generated {total_strings} strings ('{self.data_generator.distribution}')")

        # increase sample size
        search_sample_size = min(int(total_strings * 0.5), total_strings) if search_sample_size is None else search_sample_size
        search_data = random.sample(data, search_sample_size)

        for ds_name, ds_class in self.data_structures.items():
            print(f"Testing {ds_name}")

            # dummy tree for height check
            ds_instance = ds_class()
            for s in data:
                ds_instance.insertElement(s)
            print(f"{ds_name} - Tree height after insertion: {ds_instance.height()}")

            
            def test_insertion(ds, data):
                for s in data:
                    ds.insertElement(s)

            ds_for_ins = ds_class()
            ins_globals = {"test_insertion": test_insertion, "ds": ds_for_ins, "data": data}
            total_ins_time = timeit.timeit("test_insertion(ds, data)", globals=ins_globals, number=self.repeat)
            
            
            avg_ins_time = total_ins_time / (self.repeat * total_strings) if total_strings > 0 else 0

            # add side-effect
            def test_search(ds, search_data):
                count = 0
                for s in search_data:
                    if ds.searchElement(s):
                        count += 1
                return count

            ds_for_search = ds_class()
            for s in data:
                ds_for_search.insertElement(s)
            search_globals = {"test_search": test_search, "ds": ds_for_search, "search_data": search_data}
            total_search_time = timeit.timeit("test_search(ds, search_data)", globals=search_globals, number=self.repeat)
            
            avg_search_time = total_search_time / (self.repeat * search_sample_size) if search_sample_size > 0 else 0

            self.results["total_insertion_time"][ds_name] = total_ins_time
            self.results["total_search_time"][ds_name] = total_search_time
            self.results["avg_insertion_per_op"][ds_name] = avg_ins_time
            self.results["avg_search_per_op"][ds_name] = avg_search_time

            print(f"{ds_name} - Insert: {total_ins_time:.6f}s, Avg: {avg_ins_time:.9f}s/op")
            print(f"{ds_name} - Search: {total_search_time:.6f}s, Avg: {avg_search_time:.9f}s/op")

    def get_results(self):
        return self.results

# %% [markdown]
# Use the cell below to illustrate the python code you used to **fully evaluate** your three chosen search data structures and algortihms. The code below should illustrate, for example, how you made used of the **TestDataGenerator** class to generate test data of various size and properties; how you instatiated the **ExperimentalFramework** class to  evaluate each data structure using such data, collect information about their execution time, plot results, etc. Any results you illustrate in the companion PDF report should have been generated using the code below.

# %%
import matplotlib.pyplot as plt

# Test conditions
distributions = ["random", "sorted", "almost_sorted", "repetitive", "all_same", "reverse_sorted"]
string_length = 8
data_structures = {"2-3": TwoThreeTree, "LLRB": LLRBTree, "S_P": ScapegoatTree}

# Generate data_sizes with larger step
data_sizes = [0, 10, 50] + list(range(100, 4001, 300)) + [10000]  # edge case: 0, 1, 10  stress test: 10000

# Store results
all_results = {}

num_trials = 3
for size in data_sizes:
    # 为每个规模生成一个共享的随机数组
    base_gen = TestDataGenerator(data_size=size, string_length=string_length, distribution="random")
    base_gen.generate_data()  # 确保生成并缓存随机数据

    for dist in distributions:
        print(f"\n=== {dist}, size={size} ===")
        avg_results = {ds_name: {"ins": [], "search": []} for ds_name in data_structures}

        for trial in range(num_trials):
            # 使用同一个随机数据，但改变分布
            gen = TestDataGenerator(data_size=size, string_length=string_length, distribution=dist)
            gen._random_data = base_gen._random_data  # 共享随机数据
            framework = ExperimentalFramework(data_structures, gen, repeat=5)
            framework.run_experiment()  # search_sample_size dynamically adjust
            for ds_name, results in [(n, framework.get_results()) for n in data_structures]:
                avg_results[ds_name]["ins"].append(results["avg_insertion_per_op"][ds_name])
                avg_results[ds_name]["search"].append(results["avg_search_per_op"][ds_name])

        all_results[(dist, size)] = {
            ds_name: (sum(avg_results[ds_name]["ins"]) / num_trials,
                      sum(avg_results[ds_name]["search"]) / num_trials)
            for ds_name in data_structures
        }

# Plotting
def plot_results(all_results, data_sizes, distributions, ds_names):
    for dist in distributions:
        # plot insertion
        plt.figure(figsize=(12, 6))
        for ds in ds_names:
            ins_times = [all_results.get((dist, size), {}).get(ds, (0, 0))[0] * 1e5
                         for size in data_sizes]
            plt.plot(data_sizes, ins_times, marker='o', label=f"{ds} Insert", linewidth=1, markersize=4)
        plt.xticks(data_sizes[::2], rotation=45)
        plt.xlabel("Data Size")
        plt.ylabel("Avg Time per Insertion (10⁻⁵ s)")
        plt.title(f"Insertion Time - {dist}")
        plt.legend()
        plt.grid(True, which="both", ls="--")
        plt.tight_layout()
        plt.show()

        # plot search
        plt.figure(figsize=(12, 6))
        for ds in ds_names:
            search_times = [all_results.get((dist, size), {}).get(ds, (0, 0))[1] * 1e5
                            for size in data_sizes]
            plt.plot(data_sizes, search_times, marker='o', label=f"{ds} Search", linewidth=1, markersize=4)
        plt.xticks(data_sizes[::2], rotation=45)
        plt.xlabel("Data Size")
        plt.ylabel("Avg Time per Search (10⁻⁵ s)")
        plt.title(f"Search Time - {dist}")
        plt.legend()
        plt.grid(True, which="both", ls="--")
        plt.tight_layout()
        plt.show()

# Plot
ds_names = list(data_structures.keys())
plot_results(all_results, data_sizes, distributions, ds_names)
# Out:
# === random, size=0 ===
# Generated 0 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000002s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 0 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 0 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
#
# === sorted, size=0 ===
# Generated 0 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 0 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 0 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
#
# === almost_sorted, size=0 ===
# Generated 0 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 0 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 0 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
#
# === repetitive, size=0 ===
# Generated 0 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 0 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 0 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
#
# === all_same, size=0 ===
# Generated 0 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 0 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 0 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
#
# === reverse_sorted, size=0 ===
# Generated 0 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 0 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
# Generated 0 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 0
# 2-3 - Insert: 0.000001s, Avg: 0.000000000s/op
# 2-3 - Search: 0.000001s, Avg: 0.000000000s/op
# Testing LLRB
# LLRB - Tree height after insertion: 0
# LLRB - Insert: 0.000001s, Avg: 0.000000000s/op
# LLRB - Search: 0.000001s, Avg: 0.000000000s/op
# Testing S_P
# S_P - Tree height after insertion: 0
# S_P - Insert: 0.000001s, Avg: 0.000000000s/op
# S_P - Search: 0.000001s, Avg: 0.000000000s/op
#
# === random, size=10 ===
# Generated 10 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000105s, Avg: 0.000002094s/op
# 2-3 - Search: 0.000023s, Avg: 0.000000908s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000059s, Avg: 0.000001182s/op
# LLRB - Search: 0.000013s, Avg: 0.000000500s/op
# Testing S_P
# S_P - Tree height after insertion: 5
# S_P - Insert: 0.000048s, Avg: 0.000000964s/op
# S_P - Search: 0.000009s, Avg: 0.000000376s/op
# Generated 10 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000098s, Avg: 0.000001966s/op
# 2-3 - Search: 0.000019s, Avg: 0.000000760s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000053s, Avg: 0.000001062s/op
# LLRB - Search: 0.000009s, Avg: 0.000000352s/op
# Testing S_P
# S_P - Tree height after insertion: 5
# S_P - Insert: 0.000044s, Avg: 0.000000874s/op
# S_P - Search: 0.000009s, Avg: 0.000000356s/op
# Generated 10 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000094s, Avg: 0.000001876s/op
# 2-3 - Search: 0.000018s, Avg: 0.000000720s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000054s, Avg: 0.000001084s/op
# LLRB - Search: 0.000009s, Avg: 0.000000348s/op
# Testing S_P
# S_P - Tree height after insertion: 5
# S_P - Insert: 0.000040s, Avg: 0.000000808s/op
# S_P - Search: 0.000008s, Avg: 0.000000300s/op
#
# === sorted, size=10 ===
# Generated 10 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000104s, Avg: 0.000002072s/op
# 2-3 - Search: 0.000027s, Avg: 0.000001076s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000063s, Avg: 0.000001260s/op
# LLRB - Search: 0.000011s, Avg: 0.000000440s/op
# Testing S_P
# S_P - Tree height after insertion: 6
# S_P - Insert: 0.000065s, Avg: 0.000001304s/op
# S_P - Search: 0.000009s, Avg: 0.000000348s/op
# Generated 10 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000087s, Avg: 0.000001740s/op
# 2-3 - Search: 0.000018s, Avg: 0.000000732s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000048s, Avg: 0.000000962s/op
# LLRB - Search: 0.000010s, Avg: 0.000000384s/op
# Testing S_P
# S_P - Tree height after insertion: 6
# S_P - Insert: 0.000062s, Avg: 0.000001250s/op
# S_P - Search: 0.000009s, Avg: 0.000000348s/op
# Generated 10 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000100s, Avg: 0.000001996s/op
# 2-3 - Search: 0.000022s, Avg: 0.000000892s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000051s, Avg: 0.000001028s/op
# LLRB - Search: 0.000011s, Avg: 0.000000448s/op
# Testing S_P
# S_P - Tree height after insertion: 6
# S_P - Insert: 0.000078s, Avg: 0.000001552s/op
# S_P - Search: 0.000009s, Avg: 0.000000376s/op
#
# === almost_sorted, size=10 ===
# Generated 10 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000084s, Avg: 0.000001672s/op
# 2-3 - Search: 0.000018s, Avg: 0.000000708s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000042s, Avg: 0.000000850s/op
# LLRB - Search: 0.000008s, Avg: 0.000000324s/op
# Testing S_P
# S_P - Tree height after insertion: 6
# S_P - Insert: 0.000046s, Avg: 0.000000924s/op
# S_P - Search: 0.000007s, Avg: 0.000000272s/op
# Generated 10 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000079s, Avg: 0.000001582s/op
# 2-3 - Search: 0.000019s, Avg: 0.000000744s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000041s, Avg: 0.000000812s/op
# LLRB - Search: 0.000008s, Avg: 0.000000336s/op
# Testing S_P
# S_P - Tree height after insertion: 6
# S_P - Insert: 0.000039s, Avg: 0.000000772s/op
# S_P - Search: 0.000007s, Avg: 0.000000260s/op
# Generated 10 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000077s, Avg: 0.000001538s/op
# 2-3 - Search: 0.000016s, Avg: 0.000000656s/op
# Testing LLRB
# LLRB - Tree height after insertion: 5
# LLRB - Insert: 0.000046s, Avg: 0.000000928s/op
# LLRB - Search: 0.000010s, Avg: 0.000000384s/op
# Testing S_P
# S_P - Tree height after insertion: 5
# S_P - Insert: 0.000038s, Avg: 0.000000756s/op
# S_P - Search: 0.000008s, Avg: 0.000000312s/op
#
# === repetitive, size=10 ===
# Generated 10 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000099s, Avg: 0.000001976s/op
# 2-3 - Search: 0.000006s, Avg: 0.000000256s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000008s, Avg: 0.000000158s/op
# LLRB - Search: 0.000005s, Avg: 0.000000184s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.000020s, Avg: 0.000000404s/op
# S_P - Search: 0.000004s, Avg: 0.000000164s/op
# Generated 10 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000098s, Avg: 0.000001952s/op
# 2-3 - Search: 0.000006s, Avg: 0.000000248s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000008s, Avg: 0.000000168s/op
# LLRB - Search: 0.000004s, Avg: 0.000000164s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.000018s, Avg: 0.000000366s/op
# S_P - Search: 0.000003s, Avg: 0.000000140s/op
# Generated 10 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000087s, Avg: 0.000001738s/op
# 2-3 - Search: 0.000006s, Avg: 0.000000244s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000007s, Avg: 0.000000146s/op
# LLRB - Search: 0.000004s, Avg: 0.000000180s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.000019s, Avg: 0.000000374s/op
# S_P - Search: 0.000003s, Avg: 0.000000132s/op
#
# === all_same, size=10 ===
# Generated 10 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000087s, Avg: 0.000001730s/op
# 2-3 - Search: 0.000006s, Avg: 0.000000236s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000008s, Avg: 0.000000160s/op
# LLRB - Search: 0.000005s, Avg: 0.000000184s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.000018s, Avg: 0.000000350s/op
# S_P - Search: 0.000004s, Avg: 0.000000148s/op
# Generated 10 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000089s, Avg: 0.000001786s/op
# 2-3 - Search: 0.000006s, Avg: 0.000000236s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000007s, Avg: 0.000000146s/op
# LLRB - Search: 0.000004s, Avg: 0.000000168s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.000019s, Avg: 0.000000376s/op
# S_P - Search: 0.000004s, Avg: 0.000000152s/op
# Generated 10 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000087s, Avg: 0.000001736s/op
# 2-3 - Search: 0.000006s, Avg: 0.000000256s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000008s, Avg: 0.000000160s/op
# LLRB - Search: 0.000004s, Avg: 0.000000164s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.000018s, Avg: 0.000000362s/op
# S_P - Search: 0.000004s, Avg: 0.000000144s/op
#
# === reverse_sorted, size=10 ===
# Generated 10 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000077s, Avg: 0.000001546s/op
# 2-3 - Search: 0.000017s, Avg: 0.000000680s/op
# Testing LLRB
# LLRB - Tree height after insertion: 5
# LLRB - Insert: 0.000044s, Avg: 0.000000878s/op
# LLRB - Search: 0.000009s, Avg: 0.000000352s/op
# Testing S_P
# S_P - Tree height after insertion: 6
# S_P - Insert: 0.000054s, Avg: 0.000001082s/op
# S_P - Search: 0.000007s, Avg: 0.000000292s/op
# Generated 10 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000076s, Avg: 0.000001522s/op
# 2-3 - Search: 0.000017s, Avg: 0.000000700s/op
# Testing LLRB
# LLRB - Tree height after insertion: 5
# LLRB - Insert: 0.000047s, Avg: 0.000000934s/op
# LLRB - Search: 0.000009s, Avg: 0.000000376s/op
# Testing S_P
# S_P - Tree height after insertion: 6
# S_P - Insert: 0.000052s, Avg: 0.000001040s/op
# S_P - Search: 0.000008s, Avg: 0.000000328s/op
# Generated 10 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 3
# 2-3 - Insert: 0.000076s, Avg: 0.000001510s/op
# 2-3 - Search: 0.000016s, Avg: 0.000000656s/op
# Testing LLRB
# LLRB - Tree height after insertion: 5
# LLRB - Insert: 0.000044s, Avg: 0.000000878s/op
# LLRB - Search: 0.000008s, Avg: 0.000000336s/op
# Testing S_P
# S_P - Tree height after insertion: 6
# S_P - Insert: 0.000053s, Avg: 0.000001056s/op
# S_P - Search: 0.000008s, Avg: 0.000000300s/op
#
# === random, size=50 ===
# Generated 50 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000485s, Avg: 0.000001942s/op
# 2-3 - Search: 0.000124s, Avg: 0.000000990s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.000360s, Avg: 0.000001441s/op
# LLRB - Search: 0.000054s, Avg: 0.000000434s/op
# Testing S_P
# S_P - Tree height after insertion: 10
# S_P - Insert: 0.000321s, Avg: 0.000001285s/op
# S_P - Search: 0.000558s, Avg: 0.000004462s/op
# Generated 50 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000486s, Avg: 0.000001943s/op
# 2-3 - Search: 0.000123s, Avg: 0.000000982s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.000368s, Avg: 0.000001473s/op
# LLRB - Search: 0.000052s, Avg: 0.000000413s/op
# Testing S_P
# S_P - Tree height after insertion: 10
# S_P - Insert: 0.000321s, Avg: 0.000001284s/op
# S_P - Search: 0.000058s, Avg: 0.000000466s/op
# Generated 50 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000511s, Avg: 0.000002042s/op
# 2-3 - Search: 0.000134s, Avg: 0.000001068s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.000416s, Avg: 0.000001666s/op
# LLRB - Search: 0.000061s, Avg: 0.000000486s/op
# Testing S_P
# S_P - Tree height after insertion: 10
# S_P - Insert: 0.000325s, Avg: 0.000001302s/op
# S_P - Search: 0.000052s, Avg: 0.000000414s/op
#
# === sorted, size=50 ===
# Generated 50 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000500s, Avg: 0.000002001s/op
# 2-3 - Search: 0.000119s, Avg: 0.000000955s/op
# Testing LLRB
# LLRB - Tree height after insertion: 6
# LLRB - Insert: 0.000383s, Avg: 0.000001530s/op
# LLRB - Search: 0.000060s, Avg: 0.000000482s/op
# Testing S_P
# S_P - Tree height after insertion: 10
# S_P - Insert: 0.000494s, Avg: 0.000001977s/op
# S_P - Search: 0.000064s, Avg: 0.000000510s/op
# Generated 50 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000648s, Avg: 0.000002592s/op
# 2-3 - Search: 0.000161s, Avg: 0.000001288s/op
# Testing LLRB
# LLRB - Tree height after insertion: 6
# LLRB - Insert: 0.000509s, Avg: 0.000002038s/op
# LLRB - Search: 0.000077s, Avg: 0.000000618s/op
# Testing S_P
# S_P - Tree height after insertion: 10
# S_P - Insert: 0.000661s, Avg: 0.000002645s/op
# S_P - Search: 0.000091s, Avg: 0.000000726s/op
# Generated 50 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000879s, Avg: 0.000003517s/op
# 2-3 - Search: 0.000210s, Avg: 0.000001678s/op
# Testing LLRB
# LLRB - Tree height after insertion: 6
# LLRB - Insert: 0.000648s, Avg: 0.000002592s/op
# LLRB - Search: 0.000100s, Avg: 0.000000799s/op
# Testing S_P
# S_P - Tree height after insertion: 10
# S_P - Insert: 0.000730s, Avg: 0.000002920s/op
# S_P - Search: 0.000092s, Avg: 0.000000736s/op
#
# === almost_sorted, size=50 ===
# Generated 50 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.001014s, Avg: 0.000004057s/op
# 2-3 - Search: 0.000261s, Avg: 0.000002086s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.000799s, Avg: 0.000003196s/op
# LLRB - Search: 0.000131s, Avg: 0.000001050s/op
# Testing S_P
# S_P - Tree height after insertion: 10
# S_P - Insert: 0.001003s, Avg: 0.000004012s/op
# S_P - Search: 0.000151s, Avg: 0.000001210s/op
# Generated 50 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.001356s, Avg: 0.000005422s/op
# 2-3 - Search: 0.000324s, Avg: 0.000002594s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.001034s, Avg: 0.000004136s/op
# LLRB - Search: 0.000154s, Avg: 0.000001231s/op
# Testing S_P
# S_P - Tree height after insertion: 10
# S_P - Insert: 0.001396s, Avg: 0.000005586s/op
# S_P - Search: 0.000158s, Avg: 0.000001266s/op
# Generated 50 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.001506s, Avg: 0.000006026s/op
# 2-3 - Search: 0.000372s, Avg: 0.000002979s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.001046s, Avg: 0.000004185s/op
# LLRB - Search: 0.000169s, Avg: 0.000001353s/op
# Testing S_P
# S_P - Tree height after insertion: 10
# S_P - Insert: 0.001197s, Avg: 0.000004788s/op
# S_P - Search: 0.000154s, Avg: 0.000001230s/op
#
# === repetitive, size=50 ===
# Generated 50 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.001582s, Avg: 0.000006330s/op
# 2-3 - Search: 0.000172s, Avg: 0.000001378s/op
# Testing LLRB
# LLRB - Tree height after insertion: 3
# LLRB - Insert: 0.000370s, Avg: 0.000001478s/op
# LLRB - Search: 0.000084s, Avg: 0.000000670s/op
# Testing S_P
# S_P - Tree height after insertion: 4
# S_P - Insert: 0.000374s, Avg: 0.000001496s/op
# S_P - Search: 0.000066s, Avg: 0.000000528s/op
# Generated 50 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.001479s, Avg: 0.000005915s/op
# 2-3 - Search: 0.000147s, Avg: 0.000001179s/op
# Testing LLRB
# LLRB - Tree height after insertion: 3
# LLRB - Insert: 0.000321s, Avg: 0.000001285s/op
# LLRB - Search: 0.000074s, Avg: 0.000000588s/op
# Testing S_P
# S_P - Tree height after insertion: 4
# S_P - Insert: 0.000326s, Avg: 0.000001304s/op
# S_P - Search: 0.000062s, Avg: 0.000000500s/op
# Generated 50 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.001301s, Avg: 0.000005203s/op
# 2-3 - Search: 0.000136s, Avg: 0.000001090s/op
# Testing LLRB
# LLRB - Tree height after insertion: 3
# LLRB - Insert: 0.000359s, Avg: 0.000001437s/op
# LLRB - Search: 0.000090s, Avg: 0.000000722s/op
# Testing S_P
# S_P - Tree height after insertion: 4
# S_P - Insert: 0.000283s, Avg: 0.000001130s/op
# S_P - Search: 0.000058s, Avg: 0.000000462s/op
#
# === all_same, size=50 ===
# Generated 50 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.001222s, Avg: 0.000004889s/op
# 2-3 - Search: 0.000052s, Avg: 0.000000417s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000064s, Avg: 0.000000255s/op
# LLRB - Search: 0.000035s, Avg: 0.000000276s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.000173s, Avg: 0.000000690s/op
# S_P - Search: 0.000028s, Avg: 0.000000221s/op
# Generated 50 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.001101s, Avg: 0.000004402s/op
# 2-3 - Search: 0.000046s, Avg: 0.000000368s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000060s, Avg: 0.000000240s/op
# LLRB - Search: 0.000032s, Avg: 0.000000254s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.000155s, Avg: 0.000000620s/op
# S_P - Search: 0.000029s, Avg: 0.000000230s/op
# Generated 50 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000989s, Avg: 0.000003956s/op
# 2-3 - Search: 0.000042s, Avg: 0.000000338s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000055s, Avg: 0.000000220s/op
# LLRB - Search: 0.000028s, Avg: 0.000000226s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.000138s, Avg: 0.000000552s/op
# S_P - Search: 0.000023s, Avg: 0.000000182s/op
#
# === reverse_sorted, size=50 ===
# Generated 50 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000789s, Avg: 0.000003156s/op
# 2-3 - Search: 0.000191s, Avg: 0.000001528s/op
# Testing LLRB
# LLRB - Tree height after insertion: 8
# LLRB - Insert: 0.000572s, Avg: 0.000002288s/op
# LLRB - Search: 0.000081s, Avg: 0.000000650s/op
# Testing S_P
# S_P - Tree height after insertion: 10
# S_P - Insert: 0.000617s, Avg: 0.000002466s/op
# S_P - Search: 0.000066s, Avg: 0.000000529s/op
# Generated 50 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000665s, Avg: 0.000002660s/op
# 2-3 - Search: 0.000161s, Avg: 0.000001286s/op
# Testing LLRB
# LLRB - Tree height after insertion: 8
# LLRB - Insert: 0.000487s, Avg: 0.000001949s/op
# LLRB - Search: 0.000068s, Avg: 0.000000540s/op
# Testing S_P
# S_P - Tree height after insertion: 10
# S_P - Insert: 0.000501s, Avg: 0.000002005s/op
# S_P - Search: 0.000057s, Avg: 0.000000458s/op
# Generated 50 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.000553s, Avg: 0.000002212s/op
# 2-3 - Search: 0.000137s, Avg: 0.000001094s/op
# Testing LLRB
# LLRB - Tree height after insertion: 8
# LLRB - Insert: 0.000409s, Avg: 0.000001634s/op
# LLRB - Search: 0.000059s, Avg: 0.000000475s/op
# Testing S_P
# S_P - Tree height after insertion: 10
# S_P - Insert: 0.000438s, Avg: 0.000001752s/op
# S_P - Search: 0.000049s, Avg: 0.000000392s/op
#
# === random, size=100 ===
# Generated 100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.001048s, Avg: 0.000002096s/op
# 2-3 - Search: 0.000257s, Avg: 0.000001028s/op
# Testing LLRB
# LLRB - Tree height after insertion: 9
# LLRB - Insert: 0.000937s, Avg: 0.000001874s/op
# LLRB - Search: 0.000125s, Avg: 0.000000501s/op
# Testing S_P
# S_P - Tree height after insertion: 12
# S_P - Insert: 0.000637s, Avg: 0.000001274s/op
# S_P - Search: 0.000111s, Avg: 0.000000446s/op
# Generated 100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.001151s, Avg: 0.000002302s/op
# 2-3 - Search: 0.000261s, Avg: 0.000001045s/op
# Testing LLRB
# LLRB - Tree height after insertion: 9
# LLRB - Insert: 0.000907s, Avg: 0.000001813s/op
# LLRB - Search: 0.000121s, Avg: 0.000000486s/op
# Testing S_P
# S_P - Tree height after insertion: 12
# S_P - Insert: 0.000619s, Avg: 0.000001237s/op
# S_P - Search: 0.000113s, Avg: 0.000000451s/op
# Generated 100 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 5
# 2-3 - Insert: 0.001092s, Avg: 0.000002183s/op
# 2-3 - Search: 0.000294s, Avg: 0.000001175s/op
# Testing LLRB
# LLRB - Tree height after insertion: 9
# LLRB - Insert: 0.001186s, Avg: 0.000002371s/op
# LLRB - Search: 0.000176s, Avg: 0.000000703s/op
# Testing S_P
# S_P - Tree height after insertion: 12
# S_P - Insert: 0.000973s, Avg: 0.000001946s/op
# S_P - Search: 0.000177s, Avg: 0.000000708s/op
#
# === sorted, size=100 ===
# Generated 100 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.002036s, Avg: 0.000004073s/op
# 2-3 - Search: 0.000605s, Avg: 0.000002421s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.001786s, Avg: 0.000003572s/op
# LLRB - Search: 0.000251s, Avg: 0.000001004s/op
# Testing S_P
# S_P - Tree height after insertion: 11
# S_P - Insert: 0.002059s, Avg: 0.000004118s/op
# S_P - Search: 0.000256s, Avg: 0.000001026s/op
# Generated 100 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.002670s, Avg: 0.000005340s/op
# 2-3 - Search: 0.000734s, Avg: 0.000002938s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.001944s, Avg: 0.000003888s/op
# LLRB - Search: 0.000281s, Avg: 0.000001124s/op
# Testing S_P
# S_P - Tree height after insertion: 11
# S_P - Insert: 0.002092s, Avg: 0.000004184s/op
# S_P - Search: 0.000272s, Avg: 0.000001087s/op
# Generated 100 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.002274s, Avg: 0.000004549s/op
# 2-3 - Search: 0.000577s, Avg: 0.000002308s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.001507s, Avg: 0.000003014s/op
# LLRB - Search: 0.000221s, Avg: 0.000000882s/op
# Testing S_P
# S_P - Tree height after insertion: 11
# S_P - Insert: 0.001612s, Avg: 0.000003223s/op
# S_P - Search: 0.000176s, Avg: 0.000000704s/op
#
# === almost_sorted, size=100 ===
# Generated 100 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.001514s, Avg: 0.000003027s/op
# 2-3 - Search: 0.000375s, Avg: 0.000001499s/op
# Testing LLRB
# LLRB - Tree height after insertion: 8
# LLRB - Insert: 0.001157s, Avg: 0.000002315s/op
# LLRB - Search: 0.000181s, Avg: 0.000000724s/op
# Testing S_P
# S_P - Tree height after insertion: 12
# S_P - Insert: 0.001523s, Avg: 0.000003045s/op
# S_P - Search: 0.000169s, Avg: 0.000000676s/op
# Generated 100 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.001456s, Avg: 0.000002913s/op
# 2-3 - Search: 0.000355s, Avg: 0.000001419s/op
# Testing LLRB
# LLRB - Tree height after insertion: 8
# LLRB - Insert: 0.001015s, Avg: 0.000002029s/op
# LLRB - Search: 0.000136s, Avg: 0.000000545s/op
# Testing S_P
# S_P - Tree height after insertion: 12
# S_P - Insert: 0.001115s, Avg: 0.000002230s/op
# S_P - Search: 0.000125s, Avg: 0.000000498s/op
# Generated 100 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.001055s, Avg: 0.000002111s/op
# 2-3 - Search: 0.000973s, Avg: 0.000003892s/op
# Testing LLRB
# LLRB - Tree height after insertion: 8
# LLRB - Insert: 0.000805s, Avg: 0.000001609s/op
# LLRB - Search: 0.000116s, Avg: 0.000000466s/op
# Testing S_P
# S_P - Tree height after insertion: 11
# S_P - Insert: 0.001067s, Avg: 0.000002133s/op
# S_P - Search: 0.000128s, Avg: 0.000000511s/op
#
# === repetitive, size=100 ===
# Generated 100 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.001503s, Avg: 0.000003006s/op
# 2-3 - Search: 0.000211s, Avg: 0.000000844s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000516s, Avg: 0.000001032s/op
# LLRB - Search: 0.000105s, Avg: 0.000000419s/op
# Testing S_P
# S_P - Tree height after insertion: 6
# S_P - Insert: 0.000470s, Avg: 0.000000940s/op
# S_P - Search: 0.000099s, Avg: 0.000000396s/op
# Generated 100 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.002167s, Avg: 0.000004335s/op
# 2-3 - Search: 0.000291s, Avg: 0.000001165s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000639s, Avg: 0.000001278s/op
# LLRB - Search: 0.000133s, Avg: 0.000000533s/op
# Testing S_P
# S_P - Tree height after insertion: 6
# S_P - Insert: 0.000555s, Avg: 0.000001110s/op
# S_P - Search: 0.000110s, Avg: 0.000000440s/op
# Generated 100 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.002660s, Avg: 0.000005321s/op
# 2-3 - Search: 0.000315s, Avg: 0.000001260s/op
# Testing LLRB
# LLRB - Tree height after insertion: 4
# LLRB - Insert: 0.000804s, Avg: 0.000001608s/op
# LLRB - Search: 0.000155s, Avg: 0.000000621s/op
# Testing S_P
# S_P - Tree height after insertion: 6
# S_P - Insert: 0.000651s, Avg: 0.000001302s/op
# S_P - Search: 0.000148s, Avg: 0.000000590s/op
#
# === all_same, size=100 ===
# Generated 100 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.002870s, Avg: 0.000005740s/op
# 2-3 - Search: 0.000110s, Avg: 0.000000440s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000144s, Avg: 0.000000288s/op
# LLRB - Search: 0.000073s, Avg: 0.000000293s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.000380s, Avg: 0.000000760s/op
# S_P - Search: 0.000059s, Avg: 0.000000237s/op
# Generated 100 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.003112s, Avg: 0.000006224s/op
# 2-3 - Search: 0.000111s, Avg: 0.000000444s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000139s, Avg: 0.000000277s/op
# LLRB - Search: 0.000075s, Avg: 0.000000299s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.000367s, Avg: 0.000000735s/op
# S_P - Search: 0.000056s, Avg: 0.000000222s/op
# Generated 100 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.003419s, Avg: 0.000006838s/op
# 2-3 - Search: 0.000121s, Avg: 0.000000484s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000160s, Avg: 0.000000321s/op
# LLRB - Search: 0.000083s, Avg: 0.000000332s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.000400s, Avg: 0.000000799s/op
# S_P - Search: 0.000075s, Avg: 0.000000300s/op
#
# === reverse_sorted, size=100 ===
# Generated 100 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.002788s, Avg: 0.000005577s/op
# 2-3 - Search: 0.000756s, Avg: 0.000003023s/op
# Testing LLRB
# LLRB - Tree height after insertion: 9
# LLRB - Insert: 0.003430s, Avg: 0.000006859s/op
# LLRB - Search: 0.000417s, Avg: 0.000001668s/op
# Testing S_P
# S_P - Tree height after insertion: 11
# S_P - Insert: 0.003954s, Avg: 0.000007909s/op
# S_P - Search: 0.000298s, Avg: 0.000001192s/op
# Generated 100 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.004730s, Avg: 0.000009459s/op
# 2-3 - Search: 0.000920s, Avg: 0.000003681s/op
# Testing LLRB
# LLRB - Tree height after insertion: 9
# LLRB - Insert: 0.003330s, Avg: 0.000006659s/op
# LLRB - Search: 0.000398s, Avg: 0.000001592s/op
# Testing S_P
# S_P - Tree height after insertion: 11
# S_P - Insert: 0.003456s, Avg: 0.000006913s/op
# S_P - Search: 0.000324s, Avg: 0.000001295s/op
# Generated 100 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 6
# 2-3 - Insert: 0.003038s, Avg: 0.000006076s/op
# 2-3 - Search: 0.000762s, Avg: 0.000003047s/op
# Testing LLRB
# LLRB - Tree height after insertion: 9
# LLRB - Insert: 0.002202s, Avg: 0.000004404s/op
# LLRB - Search: 0.000291s, Avg: 0.000001164s/op
# Testing S_P
# S_P - Tree height after insertion: 11
# S_P - Insert: 0.003126s, Avg: 0.000006252s/op
# S_P - Search: 0.000260s, Avg: 0.000001041s/op
#
# === random, size=400 ===
# Generated 400 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 7
# 2-3 - Insert: 0.010711s, Avg: 0.000005356s/op
# 2-3 - Search: 0.003842s, Avg: 0.000003842s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.015875s, Avg: 0.000007938s/op
# LLRB - Search: 0.001609s, Avg: 0.000001609s/op
# Testing S_P
# S_P - Tree height after insertion: 15
# S_P - Insert: 0.008316s, Avg: 0.000004158s/op
# S_P - Search: 0.001480s, Avg: 0.000001480s/op
# Generated 400 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 7
# 2-3 - Insert: 0.011688s, Avg: 0.000005844s/op
# 2-3 - Search: 0.002651s, Avg: 0.000002651s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.006188s, Avg: 0.000003094s/op
# LLRB - Search: 0.000634s, Avg: 0.000000634s/op
# Testing S_P
# S_P - Tree height after insertion: 15
# S_P - Insert: 0.003061s, Avg: 0.000001530s/op
# S_P - Search: 0.000564s, Avg: 0.000000564s/op
# Generated 400 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 7
# 2-3 - Insert: 0.004577s, Avg: 0.000002289s/op
# 2-3 - Search: 0.001385s, Avg: 0.000001385s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.004569s, Avg: 0.000002284s/op
# LLRB - Search: 0.000609s, Avg: 0.000000609s/op
# Testing S_P
# S_P - Tree height after insertion: 15
# S_P - Insert: 0.003070s, Avg: 0.000001535s/op
# S_P - Search: 0.000541s, Avg: 0.000000541s/op
#
# === sorted, size=400 ===
# Generated 400 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.005373s, Avg: 0.000002687s/op
# 2-3 - Search: 0.001500s, Avg: 0.000001500s/op
# Testing LLRB
# LLRB - Tree height after insertion: 9
# LLRB - Insert: 0.004213s, Avg: 0.000002106s/op
# LLRB - Search: 0.000583s, Avg: 0.000000583s/op
# Testing S_P
# S_P - Tree height after insertion: 14
# S_P - Insert: 0.005354s, Avg: 0.000002677s/op
# S_P - Search: 0.000574s, Avg: 0.000000574s/op
# Generated 400 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.006370s, Avg: 0.000003185s/op
# 2-3 - Search: 0.001894s, Avg: 0.000001894s/op
# Testing LLRB
# LLRB - Tree height after insertion: 9
# LLRB - Insert: 0.004434s, Avg: 0.000002217s/op
# LLRB - Search: 0.000600s, Avg: 0.000000600s/op
# Testing S_P
# S_P - Tree height after insertion: 14
# S_P - Insert: 0.005381s, Avg: 0.000002691s/op
# S_P - Search: 0.000804s, Avg: 0.000000804s/op
# Generated 400 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.009005s, Avg: 0.000004503s/op
# 2-3 - Search: 0.003867s, Avg: 0.000003867s/op
# Testing LLRB
# LLRB - Tree height after insertion: 9
# LLRB - Insert: 0.010159s, Avg: 0.000005079s/op
# LLRB - Search: 0.001356s, Avg: 0.000001356s/op
# Testing S_P
# S_P - Tree height after insertion: 14
# S_P - Insert: 0.014567s, Avg: 0.000007283s/op
# S_P - Search: 0.001870s, Avg: 0.000001870s/op
#
# === almost_sorted, size=400 ===
# Generated 400 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.016870s, Avg: 0.000008435s/op
# 2-3 - Search: 0.004354s, Avg: 0.000004354s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.011717s, Avg: 0.000005858s/op
# LLRB - Search: 0.001697s, Avg: 0.000001697s/op
# Testing S_P
# S_P - Tree height after insertion: 15
# S_P - Insert: 0.014278s, Avg: 0.000007139s/op
# S_P - Search: 0.001195s, Avg: 0.000001195s/op
# Generated 400 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.007544s, Avg: 0.000003772s/op
# 2-3 - Search: 0.001638s, Avg: 0.000001638s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.004150s, Avg: 0.000002075s/op
# LLRB - Search: 0.000593s, Avg: 0.000000593s/op
# Testing S_P
# S_P - Tree height after insertion: 15
# S_P - Insert: 0.005162s, Avg: 0.000002581s/op
# S_P - Search: 0.000564s, Avg: 0.000000564s/op
# Generated 400 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.004981s, Avg: 0.000002490s/op
# 2-3 - Search: 0.001521s, Avg: 0.000001521s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.004292s, Avg: 0.000002146s/op
# LLRB - Search: 0.000604s, Avg: 0.000000604s/op
# Testing S_P
# S_P - Tree height after insertion: 15
# S_P - Insert: 0.005255s, Avg: 0.000002628s/op
# S_P - Search: 0.000600s, Avg: 0.000000600s/op
#
# === repetitive, size=400 ===
# Generated 400 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 7
# 2-3 - Insert: 0.005149s, Avg: 0.000002574s/op
# 2-3 - Search: 0.001034s, Avg: 0.000001034s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.002475s, Avg: 0.000001238s/op
# LLRB - Search: 0.000377s, Avg: 0.000000377s/op
# Testing S_P
# S_P - Tree height after insertion: 9
# S_P - Insert: 0.001594s, Avg: 0.000000797s/op
# S_P - Search: 0.000351s, Avg: 0.000000351s/op
# Generated 400 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 7
# 2-3 - Insert: 0.005113s, Avg: 0.000002556s/op
# 2-3 - Search: 0.001370s, Avg: 0.000001370s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.002603s, Avg: 0.000001301s/op
# LLRB - Search: 0.000401s, Avg: 0.000000401s/op
# Testing S_P
# S_P - Tree height after insertion: 9
# S_P - Insert: 0.001983s, Avg: 0.000000992s/op
# S_P - Search: 0.000587s, Avg: 0.000000587s/op
# Generated 400 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 7
# 2-3 - Insert: 0.009599s, Avg: 0.000004799s/op
# 2-3 - Search: 0.001618s, Avg: 0.000001618s/op
# Testing LLRB
# LLRB - Tree height after insertion: 7
# LLRB - Insert: 0.007043s, Avg: 0.000003522s/op
# LLRB - Search: 0.000998s, Avg: 0.000000998s/op
# Testing S_P
# S_P - Tree height after insertion: 9
# S_P - Insert: 0.006637s, Avg: 0.000003318s/op
# S_P - Search: 0.000902s, Avg: 0.000000902s/op
#
# === all_same, size=400 ===
# Generated 400 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.018243s, Avg: 0.000009122s/op
# 2-3 - Search: 0.000510s, Avg: 0.000000510s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000668s, Avg: 0.000000334s/op
# LLRB - Search: 0.000313s, Avg: 0.000000313s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.001822s, Avg: 0.000000911s/op
# S_P - Search: 0.000218s, Avg: 0.000000218s/op
# Generated 400 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.016043s, Avg: 0.000008021s/op
# 2-3 - Search: 0.000526s, Avg: 0.000000526s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000746s, Avg: 0.000000373s/op
# LLRB - Search: 0.000349s, Avg: 0.000000349s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.002124s, Avg: 0.000001062s/op
# S_P - Search: 0.000303s, Avg: 0.000000303s/op
# Generated 400 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.018157s, Avg: 0.000009078s/op
# 2-3 - Search: 0.000521s, Avg: 0.000000521s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.000682s, Avg: 0.000000341s/op
# LLRB - Search: 0.000346s, Avg: 0.000000346s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.001878s, Avg: 0.000000939s/op
# S_P - Search: 0.000275s, Avg: 0.000000275s/op
#
# === reverse_sorted, size=400 ===
# Generated 400 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.015805s, Avg: 0.000007903s/op
# 2-3 - Search: 0.005227s, Avg: 0.000005227s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.010181s, Avg: 0.000005090s/op
# LLRB - Search: 0.000931s, Avg: 0.000000931s/op
# Testing S_P
# S_P - Tree height after insertion: 15
# S_P - Insert: 0.007962s, Avg: 0.000003981s/op
# S_P - Search: 0.000978s, Avg: 0.000000978s/op
# Generated 400 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.007616s, Avg: 0.000003808s/op
# 2-3 - Search: 0.001891s, Avg: 0.000001891s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.006869s, Avg: 0.000003434s/op
# LLRB - Search: 0.001625s, Avg: 0.000001625s/op
# Testing S_P
# S_P - Tree height after insertion: 15
# S_P - Insert: 0.018159s, Avg: 0.000009080s/op
# S_P - Search: 0.001670s, Avg: 0.000001670s/op
# Generated 400 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.014379s, Avg: 0.000007190s/op
# 2-3 - Search: 0.004025s, Avg: 0.000004025s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.011591s, Avg: 0.000005795s/op
# LLRB - Search: 0.002419s, Avg: 0.000002419s/op
# Testing S_P
# S_P - Tree height after insertion: 15
# S_P - Insert: 0.014974s, Avg: 0.000007487s/op
# S_P - Search: 0.001376s, Avg: 0.000001376s/op
#
# === random, size=700 ===
# Generated 700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.024225s, Avg: 0.000006922s/op
# 2-3 - Search: 0.008257s, Avg: 0.000004718s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.015495s, Avg: 0.000004427s/op
# LLRB - Search: 0.001260s, Avg: 0.000000720s/op
# Testing S_P
# S_P - Tree height after insertion: 16
# S_P - Insert: 0.010647s, Avg: 0.000003042s/op
# S_P - Search: 0.001624s, Avg: 0.000000928s/op
# Generated 700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.009300s, Avg: 0.000002657s/op
# 2-3 - Search: 0.003155s, Avg: 0.000001803s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.008601s, Avg: 0.000002457s/op
# LLRB - Search: 0.001321s, Avg: 0.000000755s/op
# Testing S_P
# S_P - Tree height after insertion: 16
# S_P - Insert: 0.005150s, Avg: 0.000001471s/op
# S_P - Search: 0.001075s, Avg: 0.000000614s/op
# Generated 700 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.015710s, Avg: 0.000004489s/op
# 2-3 - Search: 0.004189s, Avg: 0.000002394s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.019009s, Avg: 0.000005431s/op
# LLRB - Search: 0.002610s, Avg: 0.000001492s/op
# Testing S_P
# S_P - Tree height after insertion: 16
# S_P - Insert: 0.011338s, Avg: 0.000003239s/op
# S_P - Search: 0.002482s, Avg: 0.000001418s/op
#
# === sorted, size=700 ===
# Generated 700 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.021021s, Avg: 0.000006006s/op
# 2-3 - Search: 0.006888s, Avg: 0.000003936s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.018515s, Avg: 0.000005290s/op
# LLRB - Search: 0.002529s, Avg: 0.000001445s/op
# Testing S_P
# S_P - Tree height after insertion: 17
# S_P - Insert: 0.030545s, Avg: 0.000008727s/op
# S_P - Search: 0.002871s, Avg: 0.000001640s/op
# Generated 700 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.019853s, Avg: 0.000005672s/op
# 2-3 - Search: 0.008967s, Avg: 0.000005124s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.020718s, Avg: 0.000005919s/op
# LLRB - Search: 0.002546s, Avg: 0.000001455s/op
# Testing S_P
# S_P - Tree height after insertion: 17
# S_P - Insert: 0.022749s, Avg: 0.000006500s/op
# S_P - Search: 0.001621s, Avg: 0.000000926s/op
# Generated 700 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.010505s, Avg: 0.000003001s/op
# 2-3 - Search: 0.007233s, Avg: 0.000004133s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.014310s, Avg: 0.000004089s/op
# LLRB - Search: 0.001388s, Avg: 0.000000793s/op
# Testing S_P
# S_P - Tree height after insertion: 17
# S_P - Insert: 0.028887s, Avg: 0.000008253s/op
# S_P - Search: 0.002796s, Avg: 0.000001598s/op
#
# === almost_sorted, size=700 ===
# Generated 700 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.026946s, Avg: 0.000007699s/op
# 2-3 - Search: 0.008267s, Avg: 0.000004724s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.017088s, Avg: 0.000004882s/op
# LLRB - Search: 0.003146s, Avg: 0.000001798s/op
# Testing S_P
# S_P - Tree height after insertion: 15
# S_P - Insert: 0.025222s, Avg: 0.000007206s/op
# S_P - Search: 0.002737s, Avg: 0.000001564s/op
# Generated 700 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.021125s, Avg: 0.000006036s/op
# 2-3 - Search: 0.007308s, Avg: 0.000004176s/op
# Testing LLRB
# LLRB - Tree height after insertion: 11
# LLRB - Insert: 0.024653s, Avg: 0.000007044s/op
# LLRB - Search: 0.002577s, Avg: 0.000001472s/op
# Testing S_P
# S_P - Tree height after insertion: 17
# S_P - Insert: 0.028358s, Avg: 0.000008102s/op
# S_P - Search: 0.002842s, Avg: 0.000001624s/op
# Generated 700 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 9
# 2-3 - Insert: 0.022073s, Avg: 0.000006306s/op
# 2-3 - Search: 0.004280s, Avg: 0.000002446s/op
# Testing LLRB
# LLRB - Tree height after insertion: 10
# LLRB - Insert: 0.008075s, Avg: 0.000002307s/op
# LLRB - Search: 0.001138s, Avg: 0.000000650s/op
# Testing S_P
# S_P - Tree height after insertion: 17
# S_P - Insert: 0.012560s, Avg: 0.000003589s/op
# S_P - Search: 0.001566s, Avg: 0.000000895s/op
#
# === repetitive, size=700 ===
# Generated 700 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.015220s, Avg: 0.000004349s/op
# 2-3 - Search: 0.001754s, Avg: 0.000001002s/op
# Testing LLRB
# LLRB - Tree height after insertion: 8
# LLRB - Insert: 0.005027s, Avg: 0.000001436s/op
# LLRB - Search: 0.000756s, Avg: 0.000000432s/op
# Testing S_P
# S_P - Tree height after insertion: 10
# S_P - Insert: 0.002711s, Avg: 0.000000775s/op
# S_P - Search: 0.000790s, Avg: 0.000000452s/op
# Generated 700 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.010205s, Avg: 0.000002916s/op
# 2-3 - Search: 0.003204s, Avg: 0.000001831s/op
# Testing LLRB
# LLRB - Tree height after insertion: 8
# LLRB - Insert: 0.007363s, Avg: 0.000002104s/op
# LLRB - Search: 0.000935s, Avg: 0.000000534s/op
# Testing S_P
# S_P - Tree height after insertion: 10
# S_P - Insert: 0.002966s, Avg: 0.000000848s/op
# S_P - Search: 0.000584s, Avg: 0.000000334s/op
# Generated 700 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 8
# 2-3 - Insert: 0.010406s, Avg: 0.000002973s/op
# 2-3 - Search: 0.001721s, Avg: 0.000000984s/op
# Testing LLRB
# ...
# LLRB - Search: 0.036390s, Avg: 0.000003639s/op
# Testing S_P
# S_P - Tree height after insertion: 21
# S_P - Insert: 0.159599s, Avg: 0.000007980s/op
# S_P - Search: 0.030735s, Avg: 0.000003073s/op
#
# === sorted, size=4000 ===
# Generated 4000 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.285534s, Avg: 0.000014277s/op
# 2-3 - Search: 0.084474s, Avg: 0.000008447s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.235739s, Avg: 0.000011787s/op
# LLRB - Search: 0.051044s, Avg: 0.000005104s/op
# Testing S_P
# S_P - Tree height after insertion: 21
# S_P - Insert: 0.308134s, Avg: 0.000015407s/op
# S_P - Search: 0.033803s, Avg: 0.000003380s/op
# Generated 4000 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.275730s, Avg: 0.000013786s/op
# 2-3 - Search: 0.088038s, Avg: 0.000008804s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.247998s, Avg: 0.000012400s/op
# LLRB - Search: 0.036363s, Avg: 0.000003636s/op
# Testing S_P
# S_P - Tree height after insertion: 21
# S_P - Insert: 0.299237s, Avg: 0.000014962s/op
# S_P - Search: 0.036352s, Avg: 0.000003635s/op
# Generated 4000 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.278467s, Avg: 0.000013923s/op
# 2-3 - Search: 0.086517s, Avg: 0.000008652s/op
# Testing LLRB
# LLRB - Tree height after insertion: 12
# LLRB - Insert: 0.243226s, Avg: 0.000012161s/op
# LLRB - Search: 0.035651s, Avg: 0.000003565s/op
# Testing S_P
# S_P - Tree height after insertion: 21
# S_P - Insert: 0.337559s, Avg: 0.000016878s/op
# S_P - Search: 0.040290s, Avg: 0.000004029s/op
#
# === almost_sorted, size=4000 ===
# Generated 4000 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.301829s, Avg: 0.000015091s/op
# 2-3 - Search: 0.090457s, Avg: 0.000009046s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.240593s, Avg: 0.000012030s/op
# LLRB - Search: 0.034192s, Avg: 0.000003419s/op
# Testing S_P
# S_P - Tree height after insertion: 20
# S_P - Insert: 0.324120s, Avg: 0.000016206s/op
# S_P - Search: 0.035474s, Avg: 0.000003547s/op
# Generated 4000 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.276827s, Avg: 0.000013841s/op
# 2-3 - Search: 0.093280s, Avg: 0.000009328s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.243259s, Avg: 0.000012163s/op
# LLRB - Search: 0.038020s, Avg: 0.000003802s/op
# Testing S_P
# S_P - Tree height after insertion: 21
# S_P - Insert: 0.311554s, Avg: 0.000015578s/op
# S_P - Search: 0.037564s, Avg: 0.000003756s/op
# Generated 4000 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.269893s, Avg: 0.000013495s/op
# 2-3 - Search: 0.086090s, Avg: 0.000008609s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.237379s, Avg: 0.000011869s/op
# LLRB - Search: 0.036850s, Avg: 0.000003685s/op
# Testing S_P
# S_P - Tree height after insertion: 21
# S_P - Insert: 0.320269s, Avg: 0.000016013s/op
# S_P - Search: 0.037205s, Avg: 0.000003721s/op
#
# === repetitive, size=4000 ===
# Generated 4000 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.274719s, Avg: 0.000013736s/op
# 2-3 - Search: 0.055911s, Avg: 0.000005591s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.190271s, Avg: 0.000009514s/op
# LLRB - Search: 0.028656s, Avg: 0.000002866s/op
# Testing S_P
# S_P - Tree height after insertion: 15
# S_P - Insert: 0.087119s, Avg: 0.000004356s/op
# S_P - Search: 0.023784s, Avg: 0.000002378s/op
# Generated 4000 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.314995s, Avg: 0.000015750s/op
# 2-3 - Search: 0.082940s, Avg: 0.000008294s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.172694s, Avg: 0.000008635s/op
# LLRB - Search: 0.024242s, Avg: 0.000002424s/op
# Testing S_P
# S_P - Tree height after insertion: 15
# S_P - Insert: 0.089917s, Avg: 0.000004496s/op
# S_P - Search: 0.023020s, Avg: 0.000002302s/op
# Generated 4000 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 10
# 2-3 - Insert: 0.318229s, Avg: 0.000015911s/op
# 2-3 - Search: 0.061756s, Avg: 0.000006176s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.185793s, Avg: 0.000009290s/op
# LLRB - Search: 0.030147s, Avg: 0.000003015s/op
# Testing S_P
# S_P - Tree height after insertion: 15
# S_P - Insert: 0.083649s, Avg: 0.000004182s/op
# S_P - Search: 0.023026s, Avg: 0.000002303s/op
#
# === all_same, size=4000 ===
# Generated 4000 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.307180s, Avg: 0.000015359s/op
# 2-3 - Search: 0.006552s, Avg: 0.000000655s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.009314s, Avg: 0.000000466s/op
# LLRB - Search: 0.004401s, Avg: 0.000000440s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.024400s, Avg: 0.000001220s/op
# S_P - Search: 0.004335s, Avg: 0.000000434s/op
# Generated 4000 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.307645s, Avg: 0.000015382s/op
# 2-3 - Search: 0.007205s, Avg: 0.000000721s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.008085s, Avg: 0.000000404s/op
# LLRB - Search: 0.005020s, Avg: 0.000000502s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.024466s, Avg: 0.000001223s/op
# S_P - Search: 0.004091s, Avg: 0.000000409s/op
# Generated 4000 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.296065s, Avg: 0.000014803s/op
# 2-3 - Search: 0.008416s, Avg: 0.000000842s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.008365s, Avg: 0.000000418s/op
# LLRB - Search: 0.004421s, Avg: 0.000000442s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.023034s, Avg: 0.000001152s/op
# S_P - Search: 0.004206s, Avg: 0.000000421s/op
#
# === reverse_sorted, size=4000 ===
# Generated 4000 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.260978s, Avg: 0.000013049s/op
# 2-3 - Search: 0.096158s, Avg: 0.000009616s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.265189s, Avg: 0.000013259s/op
# LLRB - Search: 0.038466s, Avg: 0.000003847s/op
# Testing S_P
# S_P - Tree height after insertion: 21
# S_P - Insert: 0.337856s, Avg: 0.000016893s/op
# S_P - Search: 0.036799s, Avg: 0.000003680s/op
# Generated 4000 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.227486s, Avg: 0.000011374s/op
# 2-3 - Search: 0.082996s, Avg: 0.000008300s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.236979s, Avg: 0.000011849s/op
# LLRB - Search: 0.031139s, Avg: 0.000003114s/op
# Testing S_P
# S_P - Tree height after insertion: 21
# S_P - Insert: 0.299546s, Avg: 0.000014977s/op
# S_P - Search: 0.032809s, Avg: 0.000003281s/op
# Generated 4000 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.217338s, Avg: 0.000010867s/op
# 2-3 - Search: 0.081869s, Avg: 0.000008187s/op
# Testing LLRB
# LLRB - Tree height after insertion: 17
# LLRB - Insert: 0.256555s, Avg: 0.000012828s/op
# LLRB - Search: 0.038931s, Avg: 0.000003893s/op
# Testing S_P
# S_P - Tree height after insertion: 21
# S_P - Insert: 0.284135s, Avg: 0.000014207s/op
# S_P - Search: 0.025150s, Avg: 0.000002515s/op
#
# === random, size=10000 ===
# Generated 10000 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.644323s, Avg: 0.000012886s/op
# 2-3 - Search: 0.263016s, Avg: 0.000010521s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.743197s, Avg: 0.000014864s/op
# LLRB - Search: 0.102291s, Avg: 0.000004092s/op
# Testing S_P
# S_P - Tree height after insertion: 23
# S_P - Insert: 0.456841s, Avg: 0.000009137s/op
# S_P - Search: 0.094492s, Avg: 0.000003780s/op
# Generated 10000 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.806156s, Avg: 0.000016123s/op
# 2-3 - Search: 0.287640s, Avg: 0.000011506s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.768889s, Avg: 0.000015378s/op
# LLRB - Search: 0.101456s, Avg: 0.000004058s/op
# Testing S_P
# S_P - Tree height after insertion: 23
# S_P - Insert: 0.464816s, Avg: 0.000009296s/op
# S_P - Search: 0.087192s, Avg: 0.000003488s/op
# Generated 10000 strings ('random')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.755956s, Avg: 0.000015119s/op
# 2-3 - Search: 0.259841s, Avg: 0.000010394s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.721422s, Avg: 0.000014428s/op
# LLRB - Search: 0.131909s, Avg: 0.000005276s/op
# Testing S_P
# S_P - Tree height after insertion: 23
# S_P - Insert: 0.439876s, Avg: 0.000008798s/op
# S_P - Search: 0.094577s, Avg: 0.000003783s/op
#
# === sorted, size=10000 ===
# Generated 10000 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 13
# 2-3 - Insert: 0.710994s, Avg: 0.000014220s/op
# 2-3 - Search: 0.286257s, Avg: 0.000011450s/op
# Testing LLRB
# LLRB - Tree height after insertion: 14
# LLRB - Insert: 0.633109s, Avg: 0.000012662s/op
# LLRB - Search: 0.102598s, Avg: 0.000004104s/op
# Testing S_P
# S_P - Tree height after insertion: 23
# S_P - Insert: 0.922439s, Avg: 0.000018449s/op
# S_P - Search: 0.114637s, Avg: 0.000004585s/op
# Generated 10000 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 13
# 2-3 - Insert: 0.706407s, Avg: 0.000014128s/op
# 2-3 - Search: 0.285531s, Avg: 0.000011421s/op
# Testing LLRB
# LLRB - Tree height after insertion: 14
# LLRB - Insert: 0.636916s, Avg: 0.000012738s/op
# LLRB - Search: 0.095332s, Avg: 0.000003813s/op
# Testing S_P
# S_P - Tree height after insertion: 23
# S_P - Insert: 0.884327s, Avg: 0.000017687s/op
# S_P - Search: 0.106510s, Avg: 0.000004260s/op
# Generated 10000 strings ('sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 13
# 2-3 - Insert: 0.714397s, Avg: 0.000014288s/op
# 2-3 - Search: 0.290664s, Avg: 0.000011627s/op
# Testing LLRB
# LLRB - Tree height after insertion: 14
# LLRB - Insert: 0.632748s, Avg: 0.000012655s/op
# LLRB - Search: 0.097886s, Avg: 0.000003915s/op
# Testing S_P
# S_P - Tree height after insertion: 23
# S_P - Insert: 0.879080s, Avg: 0.000017582s/op
# S_P - Search: 0.110529s, Avg: 0.000004421s/op
#
# === almost_sorted, size=10000 ===
# Generated 10000 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 13
# 2-3 - Insert: 0.750120s, Avg: 0.000015002s/op
# 2-3 - Search: 0.302531s, Avg: 0.000012101s/op
# Testing LLRB
# LLRB - Tree height after insertion: 14
# LLRB - Insert: 0.645337s, Avg: 0.000012907s/op
# LLRB - Search: 0.098812s, Avg: 0.000003952s/op
# Testing S_P
# S_P - Tree height after insertion: 23
# S_P - Insert: 0.883202s, Avg: 0.000017664s/op
# S_P - Search: 0.103056s, Avg: 0.000004122s/op
# Generated 10000 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 13
# 2-3 - Insert: 0.725545s, Avg: 0.000014511s/op
# 2-3 - Search: 0.289359s, Avg: 0.000011574s/op
# Testing LLRB
# LLRB - Tree height after insertion: 14
# LLRB - Insert: 0.642406s, Avg: 0.000012848s/op
# LLRB - Search: 0.101337s, Avg: 0.000004053s/op
# Testing S_P
# S_P - Tree height after insertion: 23
# S_P - Insert: 0.918509s, Avg: 0.000018370s/op
# S_P - Search: 0.112066s, Avg: 0.000004483s/op
# Generated 10000 strings ('almost_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 13
# 2-3 - Insert: 0.707371s, Avg: 0.000014147s/op
# 2-3 - Search: 0.289824s, Avg: 0.000011593s/op
# Testing LLRB
# LLRB - Tree height after insertion: 15
# LLRB - Insert: 0.640919s, Avg: 0.000012818s/op
# LLRB - Search: 0.110551s, Avg: 0.000004422s/op
# Testing S_P
# S_P - Tree height after insertion: 23
# S_P - Insert: 0.887194s, Avg: 0.000017744s/op
# S_P - Search: 0.107943s, Avg: 0.000004318s/op
#
# === repetitive, size=10000 ===
# Generated 10000 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.740333s, Avg: 0.000014807s/op
# 2-3 - Search: 0.161533s, Avg: 0.000006461s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.481009s, Avg: 0.000009620s/op
# LLRB - Search: 0.068674s, Avg: 0.000002747s/op
# Testing S_P
# S_P - Tree height after insertion: 18
# S_P - Insert: 0.251782s, Avg: 0.000005036s/op
# S_P - Search: 0.065821s, Avg: 0.000002633s/op
# Generated 10000 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.769012s, Avg: 0.000015380s/op
# 2-3 - Search: 0.167618s, Avg: 0.000006705s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.492969s, Avg: 0.000009859s/op
# LLRB - Search: 0.068834s, Avg: 0.000002753s/op
# Testing S_P
# S_P - Tree height after insertion: 18
# S_P - Insert: 0.262562s, Avg: 0.000005251s/op
# S_P - Search: 0.063538s, Avg: 0.000002542s/op
# Generated 10000 strings ('repetitive')
# Testing 2-3
# 2-3 - Tree height after insertion: 11
# 2-3 - Insert: 0.746527s, Avg: 0.000014931s/op
# 2-3 - Search: 0.154711s, Avg: 0.000006188s/op
# Testing LLRB
# LLRB - Tree height after insertion: 13
# LLRB - Insert: 0.491291s, Avg: 0.000009826s/op
# LLRB - Search: 0.071061s, Avg: 0.000002842s/op
# Testing S_P
# S_P - Tree height after insertion: 18
# S_P - Insert: 0.251625s, Avg: 0.000005032s/op
# S_P - Search: 0.067709s, Avg: 0.000002708s/op
#
# === all_same, size=10000 ===
# Generated 10000 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 13
# 2-3 - Insert: 0.761035s, Avg: 0.000015221s/op
# 2-3 - Search: 0.016344s, Avg: 0.000000654s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.019127s, Avg: 0.000000383s/op
# LLRB - Search: 0.011626s, Avg: 0.000000465s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.058107s, Avg: 0.000001162s/op
# S_P - Search: 0.010391s, Avg: 0.000000416s/op
# Generated 10000 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 13
# 2-3 - Insert: 0.783219s, Avg: 0.000015664s/op
# 2-3 - Search: 0.015809s, Avg: 0.000000632s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.017948s, Avg: 0.000000359s/op
# LLRB - Search: 0.011689s, Avg: 0.000000468s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.061667s, Avg: 0.000001233s/op
# S_P - Search: 0.009087s, Avg: 0.000000363s/op
# Generated 10000 strings ('all_same')
# Testing 2-3
# 2-3 - Tree height after insertion: 13
# 2-3 - Insert: 0.722328s, Avg: 0.000014447s/op
# 2-3 - Search: 0.015154s, Avg: 0.000000606s/op
# Testing LLRB
# LLRB - Tree height after insertion: 1
# LLRB - Insert: 0.019616s, Avg: 0.000000392s/op
# LLRB - Search: 0.012514s, Avg: 0.000000501s/op
# Testing S_P
# S_P - Tree height after insertion: 1
# S_P - Insert: 0.060333s, Avg: 0.000001207s/op
# S_P - Search: 0.009944s, Avg: 0.000000398s/op
#
# === reverse_sorted, size=10000 ===
# Generated 10000 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 13
# 2-3 - Insert: 0.665532s, Avg: 0.000013311s/op
# 2-3 - Search: 0.284323s, Avg: 0.000011373s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.694633s, Avg: 0.000013893s/op
# LLRB - Search: 0.104175s, Avg: 0.000004167s/op
# Testing S_P
# S_P - Tree height after insertion: 23
# S_P - Insert: 0.861683s, Avg: 0.000017234s/op
# S_P - Search: 0.101746s, Avg: 0.000004070s/op
# Generated 10000 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 13
# 2-3 - Insert: 0.667907s, Avg: 0.000013358s/op
# 2-3 - Search: 0.277562s, Avg: 0.000011102s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.662449s, Avg: 0.000013249s/op
# LLRB - Search: 0.094660s, Avg: 0.000003786s/op
# Testing S_P
# S_P - Tree height after insertion: 23
# S_P - Insert: 0.872404s, Avg: 0.000017448s/op
# S_P - Search: 0.094501s, Avg: 0.000003780s/op
# Generated 10000 strings ('reverse_sorted')
# Testing 2-3
# 2-3 - Tree height after insertion: 13
# 2-3 - Insert: 0.700145s, Avg: 0.000014003s/op
# 2-3 - Search: 0.302467s, Avg: 0.000012099s/op
# Testing LLRB
# LLRB - Tree height after insertion: 18
# LLRB - Insert: 0.676718s, Avg: 0.000013534s/op
# LLRB - Search: 0.100238s, Avg: 0.000004010s/op
# Testing S_P
# S_P - Tree height after insertion: 23
# S_P - Insert: 0.859636s, Avg: 0.000017193s/op
# S_P - Search: 0.092344s, Avg: 0.000003694s/op
